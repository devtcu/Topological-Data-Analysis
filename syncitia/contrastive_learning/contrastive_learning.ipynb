# %% [markdown]
# # Graph Contrastive Learning for Nuclei Coordinate Prediction
#
# Here I try to show how we can apply contrastive learning techniques to improve our graph neural network's ability to predict nuclei coordinates in syncytial tissue. Graph contrastive learning helps the model learn more robust representations by creating multiple augmented views of the graph data. This way we might be able to uncover topological patterns in our data. This notebook is also just a contained version of the rest of the directory, where you can run the python code

# %%
import sys
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from torch_geometric.utils import to_networkx

#parent directory to path for importing local modules
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(''))))
sys.path.append('..')  #parent directory
sys.path.append('../GCN')  #GCN directory for gcn_layer

from data_utils import load_data, build_graph, create_coordinate_prediction_data
from contrastive_gcn import ContrastiveGCN
from contrastive_utils import train_contrastive_model, evaluate_contrastive_model, create_graph_views

# %% [markdown]
# ## Load and prepare data
#
# let's load our nuclei coordinates and build a Delaunay triangulation graph.

# %%
coordinates = load_data('../nuclei-coordinates.csv')  
print(f"Loaded {len(coordinates)} nuclei")

#building the actual graph
G, _ = build_graph(coordinates) #build_graph has two return values, so we discard the second with _
print(f"Graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# Create coordinate prediction data
print("---Creating coordinate prediction task-----")
data = create_coordinate_prediction_data(coordinates, G, missing_fraction=0.25)

print("--Final Overview--")
print(f"Total nodes: {data.x.shape[0]}")
print(f"Visible nodes: {data.visible_mask.sum().item()}")
print(f"Hidden nodes: {data.hidden_mask.sum().item()}")
print(f"Edges: {data.edge_index.shape[1]}")
print(f"Node features: {data.x.shape[1]} dimensions")
# Out:
# Loaded 3340 nuclei
# Graph: 3340 nodes, 9992 edges
# ---Creating coordinate prediction task-----
# Hiding 1050 nodes (31.4%) in 5 clusters
# Keeping 2290 nodes visible for training
# --Final Overview--
# Total nodes: 3340
# Visible nodes: 2290
# Hidden nodes: 1050
# Edges: 19984
# Node features: 6 dimensions

# %% [markdown]
# ## Visualize graph augmentations
#
# Graph contrastive learning relies on creating different "views" of the same graph through augmentations. now let us visualize what these look like.

# %%
def visualize_graph_views(data, edge_dropout, feature_mask):
    """lets see different augmented views of the graph"""
    # two augmented views
    view1, view2 = create_graph_views(data, edge_dropout_prob=edge_dropout, feature_mask_prob=feature_mask)
    
    # convert this to NetworkX for visualization
    G_original = to_networkx(data, to_undirected=True)
    G_view1 = to_networkx(view1, to_undirected=True)
    G_view2 = to_networkx(view2, to_undirected=True)
    
    #Calculate edge differences
    original_edges = set(G_original.edges())
    view1_edges = set(G_view1.edges())
    view2_edges = set(G_view2.edges())
    
    dropped_edges1 = original_edges - view1_edges
    dropped_edges2 = original_edges - view2_edges
    
    # Count the differences
    print(f"Original graph: {len(original_edges)} edges")
    print(f"View 1: {len(view1_edges)} edges ({len(dropped_edges1)} dropped)")
    print(f"View 2: {len(view2_edges)} edges ({len(dropped_edges2)} dropped)")
    
    # get a small subgraph for visualization (100 nodes)
    nodes_to_vis = list(range(100))
    
    sub_original = G_original.subgraph(nodes_to_vis)
    sub_view1 = G_view1.subgraph(nodes_to_vis)
    sub_view2 = G_view2.subgraph(nodes_to_vis)
    

    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    nx.draw_networkx(sub_original, node_size=30, with_labels=False)
    plt.title(f"Original Graph\n{len(sub_original.edges())} edges")
    
    plt.subplot(1, 3, 2)
    nx.draw_networkx(sub_view1, node_size=30, with_labels=False)
    plt.title(f"Augmented View 1\n{len(sub_view1.edges())} edges")
    
    plt.subplot(1, 3, 3)
    nx.draw_networkx(sub_view2, node_size=30, with_labels=False)
    plt.title(f"Augmented View 2\n{len(sub_view2.edges())} edges")
    
    plt.tight_layout()
    plt.show()

# visualize graph augmentations
visualize_graph_views(data, edge_dropout=0.001, feature_mask=0.01)
# Out:
# Original graph: 9992 edges
# View 1: 9980 edges (12 dropped)
# View 2: 9982 edges (10 dropped)

# %% [markdown]
# ## Initialize the contrastive learning model
#
# Our ContrastiveGCN model:
# - Uses higher-order GCN layers for feature extraction
# - Has projection head for contrastive learning
# - has a coordinate prediction head for the main task

# %%
# initialize contrastive model
contrastive_model = ContrastiveGCN(
    in_channels=data.x.shape[1],  # input feature dimensions
    hidden_channels=128,          # hidden layer size
    proj_dim=64,                  # projection dimension for contrastive learning
    tau=0.5                       # ttemperature parameter
)

# We can see the model details better
print(f"Contrastive model parameters: {sum(p.numel() for p in contrastive_model.parameters()):,}")
print(f"Model architecture:\n{contrastive_model}")
# Out:
# Contrastive model parameters: 19,622
# Model architecture:
# ContrastiveGCN(
#   (conv1): HigherOrderGCNLayer(
#     (conv): GCNConv(6, 128)
#   )
#   (conv2): HigherOrderGCNLayer(
#     (conv): GCNConv(128, 64)
#   )
#   (proj): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#   )
#   (coord_head): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=2, bias=True)
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ## Contrastive Loss Function
#
# The contrastive loss encourages the model to learn similar representations for the same nodes in different augmented views of the graph.

# %%
# now we get to demonstrate how contrastive the loss works!
def demo_contrastive_loss():
    # toy embeddings for demonstration
    batch_size = 10
    embedding_dim = 64
    
    # Same nodes, different views - this would what is referred to as an anchor (original data) and its augmented pair (a slightly altered version of the originla anchor)
    z1 = torch.randn(batch_size, embedding_dim)
    z2 = z1 + 0.1 * torch.randn(batch_size, embedding_dim)  # Similar to z1 (positive pairs) - the 0.1 is just adding a bit of noise to simulate augmentation
    
    #Different nodes (negative pairs) - 
    z3 = torch.randn(batch_size, embedding_dim)
    
    # Lets calculate losses
    model = ContrastiveGCN(in_channels=data.x.shape[1], hidden_channels=64, proj_dim=embedding_dim)
    pos_loss = model.contrastive_loss(z1, z2)
    neg_loss = model.contrastive_loss(z1, z3)
    
    print(f"Contrastive loss between similar embeddings: {pos_loss.item():.4f}")
    print(f"Contrastive loss between different embeddings: {neg_loss.item():.4f}")
    print(f"Difference (should be positive): {neg_loss.item() - pos_loss.item():.4f}")
    
    # Visualize similarity matrices
    z1_norm = torch.nn.functional.normalize(z1, dim=1)
    z2_norm = torch.nn.functional.normalize(z2, dim=1)
    z3_norm = torch.nn.functional.normalize(z3, dim=1)
    
    sim_pos = torch.mm(z1_norm, z2_norm.t())
    sim_neg = torch.mm(z1_norm, z3_norm.t())
    
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.imshow(sim_pos.detach(), cmap='viridis')
    plt.colorbar()
    plt.title("Similarity Matrix: Positive Pairs\n(Diagonal should be bright)")
    
    plt.subplot(1, 2, 2)
    plt.imshow(sim_neg.detach(), cmap='viridis')
    plt.colorbar()
    plt.title("Similarity Matrix: Negative Pairs\n(Should be more random)")
    
    plt.tight_layout()
    plt.show()

# Demo the contrastive loss
demo_contrastive_loss()
# Out:
# Contrastive loss between similar embeddings: 0.8177
# Contrastive loss between different embeddings: 2.3066
# Difference (should be positive): 1.4889

# %% [markdown]
# ### In the positive grid (right), we have a 10×10 matrix where:
#
# - Rows = nodes from embeddings z1 (view 1)
# - Columns = nodes from embeddings z2 (view 2)
# - Each cell [i,j] = cosine similarity between node i in view 1 and node j in view 2
# - The Diagonal (sim_pos[i,i]):
#
# Shows similarity between the same node in two different views.
# Should be BRIGHT/HIGH because node 0 in view 1 should be similar to node 0 in view 2.
# Diagonal = positive pairs (same nodes, different augmented views).
#
#
# ### In the negative grid (left), we have a 10×10 matrix where:
#
# Rows = nodes from embeddings z1 (view 1)
# Columns = nodes from embeddings z3 (completely different nodes)
# Each cell [i,j] = cosine similarity between node i from view 1 and node j from different nodes
# The Entire Matrix (including diagonal):
#
# Should be DARK/LOW everywhere because these are all different nodes
# No special diagonal pattern expected - all similarities should be low and random

# %% [markdown]
# ## Training with Contrastive Learning
#
# Now let's train our model with the contrastive learning objective. We'll train for a limited number of epochs here, but for the full implementation we can go ahead and run the `main_contrastive.py` script in the main directory.

# %%
# FORCE RELOAD ALL MODULES to pick up any changes you made
import importlib
import sys

# Reload contrastive_utils (this is where your changes are)
import contrastive_utils as cu
cu = importlib.reload(cu)
from contrastive_utils import (
    train_contrastive_model,
    evaluate_contrastive_model,
    create_graph_views,
)
print("✓ Reloaded contrastive_utils - your changes should now be active!")

# Also reload contrastive_gcn in case you changed that too
import contrastive_gcn as cg
cg = importlib.reload(cg)
from contrastive_gcn import ContrastiveGCN
print("✓ Reloaded contrastive_gcn")

print("\nNow run the visualization cell again to see if your changes took effect!")

# %%
# reload GCN modules and recreate the model to pick up updated layer signatures
import importlib
import sys
sys.path.append('../GCN') 

import gcn_layer as gl
import contrastive_gcn as cg

_ = importlib.reload(gl)
cg = importlib.reload(cg)
from contrastive_gcn import ContrastiveGCN

# Recreate model so its conv layers use the reloaded HigherOrderGCNLayer
contrastive_model = ContrastiveGCN(
    in_channels=data.x.shape[1],
    hidden_channels=128,
    proj_dim=64,
    tau=0.5,
)

# %%
#setup optimizer and loss function
optimizer = torch.optim.Adam(contrastive_model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = torch.nn.MSELoss()

# compute adj_powers for the model (example: up to 3rd power)
def compute_adj_powers(G, max_power=3):
    import scipy.sparse as sp
    A = nx.to_scipy_sparse_array(G, format='csr')
    adj_powers = [torch.tensor((A ** k).toarray(), dtype=torch.float32) for k in range(1, max_power + 1)]
    return adj_powers

# Note: We don't need adj_powers for the current implementation

# Train for just 10 epochs for demonstration

import time
start = time.time()
try:
    contrastive_model, train_losses = train_contrastive_model(
        contrastive_model,
        data,
        optimizer,
        criterion,
        num_epochs=500,
        lambda_contrast=0.1,
        edge_dropout_prob=0.1,      # milder augmentation for stability
        feature_mask_prob=0.1,      # milder feature masking
        log_every=3,                # print every epoch for visibility
    )
    print(f"Training finished in {time.time() - start:.1f}s")
except Exception as e:
    import traceback
    print("Training failed with error:\n", e)
    traceback.print_exc()
    raise


plt.figure(figsize=(8, 4))
plt.plot(train_losses, marker='o', linewidth=1)
plt.title("Contrastive Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# Epoch 000 | Total: 4210.8667 | Coord: 4210.1924 | Contrast: 6.7446 | MSE: 4057.00 | MeanDist: 85.32 μm
# Epoch 003 | Total: 4226.7100 | Coord: 4226.0098 | Contrast: 7.0038 | MSE: 4116.21 | MeanDist: 84.67 μm
# Epoch 006 | Total: 4037.0852 | Coord: 4036.3958 | Contrast: 6.8943 | MSE: 4033.58 | MeanDist: 84.78 μm
# Epoch 009 | Total: 4158.6704 | Coord: 4157.9868 | Contrast: 6.8373 | MSE: 4014.55 | MeanDist: 84.65 μm
# Epoch 012 | Total: 4118.3765 | Coord: 4117.6924 | Contrast: 6.8420 | MSE: 4028.18 | MeanDist: 84.23 μm
# Epoch 015 | Total: 4086.5815 | Coord: 4085.8999 | Contrast: 6.8155 | MSE: 4009.47 | MeanDist: 84.05 μm
# Epoch 018 | Total: 4074.4546 | Coord: 4073.7751 | Contrast: 6.7947 | MSE: 3971.28 | MeanDist: 84.00 μm
# Epoch 021 | Total: 4025.9480 | Coord: 4025.2695 | Contrast: 6.7854 | MSE: 3957.24 | MeanDist: 83.76 μm
# Epoch 024 | Total: 4023.0391 | Coord: 4022.3608 | Contrast: 6.7810 | MSE: 3948.09 | MeanDist: 83.47 μm
# Epoch 027 | Total: 4079.1018 | Coord: 4078.4263 | Contrast: 6.7549 | MSE: 3926.34 | MeanDist: 83.27 μm
# Epoch 030 | Total: 3944.6899 | Coord: 3944.0144 | Contrast: 6.7559 | MSE: 3903.64 | MeanDist: 83.07 μm
# Epoch 033 | Total: 3990.0183 | Coord: 3989.3433 | Contrast: 6.7503 | MSE: 3887.59 | MeanDist: 82.81 μm
# Epoch 036 | Total: 4007.1599 | Coord: 4006.4829 | Contrast: 6.7712 | MSE: 3873.54 | MeanDist: 82.55 μm
# Epoch 039 | Total: 3923.8506 | Coord: 3923.1768 | Contrast: 6.7383 | MSE: 3849.75 | MeanDist: 82.32 μm
# Epoch 042 | Total: 3886.0730 | Coord: 3885.3977 | Contrast: 6.7535 | MSE: 3828.66 | MeanDist: 82.07 μm
# Epoch 045 | Total: 3920.3323 | Coord: 3919.6562 | Contrast: 6.7607 | MSE: 3812.54 | MeanDist: 81.80 μm
# Epoch 048 | Total: 3877.0957 | Coord: 3876.4214 | Contrast: 6.7437 | MSE: 3779.35 | MeanDist: 81.65 μm
# Epoch 051 | Total: 3789.1602 | Coord: 3788.4839 | Contrast: 6.7631 | MSE: 3761.77 | MeanDist: 81.34 μm
# Epoch 054 | Total: 3884.4648 | Coord: 3883.7905 | Contrast: 6.7436 | MSE: 3754.50 | MeanDist: 80.98 μm
# Epoch 057 | Total: 3799.1675 | Coord: 3798.4939 | Contrast: 6.7367 | MSE: 3723.37 | MeanDist: 80.74 μm
# Epoch 060 | Total: 3831.7031 | Coord: 3831.0293 | Contrast: 6.7373 | MSE: 3700.20 | MeanDist: 80.45 μm
# Epoch 063 | Total: 3819.2429 | Coord: 3818.5691 | Contrast: 6.7392 | MSE: 3674.32 | MeanDist: 80.18 μm
# Epoch 066 | Total: 3788.6833 | Coord: 3788.0105 | Contrast: 6.7291 | MSE: 3657.15 | MeanDist: 79.81 μm
# Epoch 069 | Total: 3718.1921 | Coord: 3717.5193 | Contrast: 6.7293 | MSE: 3639.09 | MeanDist: 79.48 μm
# Epoch 072 | Total: 3716.0168 | Coord: 3715.3447 | Contrast: 6.7202 | MSE: 3618.22 | MeanDist: 79.19 μm
# Epoch 075 | Total: 3778.3420 | Coord: 3777.6682 | Contrast: 6.7374 | MSE: 3585.96 | MeanDist: 79.10 μm
# Epoch 078 | Total: 3762.4890 | Coord: 3761.8152 | Contrast: 6.7392 | MSE: 3580.56 | MeanDist: 78.65 μm
# Epoch 081 | Total: 3756.1414 | Coord: 3755.4668 | Contrast: 6.7466 | MSE: 3557.19 | MeanDist: 78.44 μm
# Epoch 084 | Total: 3710.2297 | Coord: 3709.5564 | Contrast: 6.7343 | MSE: 3527.22 | MeanDist: 78.36 μm
# Epoch 087 | Total: 3637.5598 | Coord: 3636.8862 | Contrast: 6.7367 | MSE: 3525.34 | MeanDist: 77.92 μm
# Epoch 090 | Total: 3680.2849 | Coord: 3679.6121 | Contrast: 6.7294 | MSE: 3492.85 | MeanDist: 77.76 μm
# Epoch 093 | Total: 3575.7258 | Coord: 3575.0530 | Contrast: 6.7292 | MSE: 3476.04 | MeanDist: 77.41 μm
# Epoch 096 | Total: 3663.9324 | Coord: 3663.2600 | Contrast: 6.7243 | MSE: 3475.47 | MeanDist: 76.95 μm
# Epoch 099 | Total: 3546.0852 | Coord: 3545.4126 | Contrast: 6.7269 | MSE: 3443.76 | MeanDist: 76.89 μm
# Epoch 102 | Total: 3560.9097 | Coord: 3560.2373 | Contrast: 6.7238 | MSE: 3422.48 | MeanDist: 76.96 μm
# Epoch 105 | Total: 3559.4905 | Coord: 3558.8184 | Contrast: 6.7203 | MSE: 3436.92 | MeanDist: 76.36 μm
# Epoch 108 | Total: 3557.1658 | Coord: 3556.4929 | Contrast: 6.7274 | MSE: 3394.86 | MeanDist: 76.45 μm
# Epoch 111 | Total: 3608.6885 | Coord: 3608.0151 | Contrast: 6.7332 | MSE: 3381.02 | MeanDist: 76.37 μm
# Epoch 114 | Total: 3527.1340 | Coord: 3526.4624 | Contrast: 6.7174 | MSE: 3419.28 | MeanDist: 75.90 μm
# Epoch 117 | Total: 3523.7893 | Coord: 3523.1187 | Contrast: 6.7056 | MSE: 3362.17 | MeanDist: 76.03 μm
# Epoch 120 | Total: 3547.4163 | Coord: 3546.7434 | Contrast: 6.7282 | MSE: 3353.72 | MeanDist: 76.26 μm
# Epoch 123 | Total: 3636.2986 | Coord: 3635.6250 | Contrast: 6.7348 | MSE: 3356.14 | MeanDist: 75.24 μm
# Epoch 126 | Total: 3621.0928 | Coord: 3620.4216 | Contrast: 6.7106 | MSE: 3325.90 | MeanDist: 75.43 μm
# Epoch 129 | Total: 3587.0598 | Coord: 3586.3882 | Contrast: 6.7174 | MSE: 3318.65 | MeanDist: 75.57 μm
# Epoch 132 | Total: 3476.8350 | Coord: 3476.1648 | Contrast: 6.7024 | MSE: 3307.28 | MeanDist: 75.14 μm
# Epoch 135 | Total: 3490.2175 | Coord: 3489.5461 | Contrast: 6.7138 | MSE: 3298.21 | MeanDist: 75.04 μm
# Epoch 138 | Total: 3399.7278 | Coord: 3399.0547 | Contrast: 6.7298 | MSE: 3290.06 | MeanDist: 74.83 μm
# Epoch 141 | Total: 3446.6060 | Coord: 3445.9348 | Contrast: 6.7110 | MSE: 3285.49 | MeanDist: 74.51 μm
# Epoch 144 | Total: 3393.3728 | Coord: 3392.7012 | Contrast: 6.7163 | MSE: 3275.26 | MeanDist: 74.79 μm
# Epoch 147 | Total: 3406.5413 | Coord: 3405.8701 | Contrast: 6.7120 | MSE: 3269.11 | MeanDist: 74.50 μm
# Epoch 150 | Total: 3361.5488 | Coord: 3360.8779 | Contrast: 6.7095 | MSE: 3264.12 | MeanDist: 74.34 μm
# Epoch 153 | Total: 3401.2617 | Coord: 3400.5920 | Contrast: 6.6969 | MSE: 3254.22 | MeanDist: 74.27 μm
# Epoch 156 | Total: 3552.1223 | Coord: 3551.4507 | Contrast: 6.7162 | MSE: 3247.42 | MeanDist: 73.95 μm
# Epoch 159 | Total: 3447.9021 | Coord: 3447.2319 | Contrast: 6.7009 | MSE: 3241.74 | MeanDist: 73.73 μm
# Epoch 162 | Total: 3421.3118 | Coord: 3420.6414 | Contrast: 6.7050 | MSE: 3230.74 | MeanDist: 73.98 μm
# Epoch 165 | Total: 3363.1519 | Coord: 3362.4814 | Contrast: 6.7034 | MSE: 3223.72 | MeanDist: 73.67 μm
# Epoch 168 | Total: 3423.4507 | Coord: 3422.7810 | Contrast: 6.6960 | MSE: 3216.76 | MeanDist: 73.76 μm
# Epoch 171 | Total: 3437.0408 | Coord: 3436.3713 | Contrast: 6.6941 | MSE: 3209.66 | MeanDist: 73.35 μm
# Epoch 174 | Total: 3389.2803 | Coord: 3388.6104 | Contrast: 6.6986 | MSE: 3203.37 | MeanDist: 73.50 μm
# Epoch 177 | Total: 3376.1301 | Coord: 3375.4592 | Contrast: 6.7090 | MSE: 3198.25 | MeanDist: 73.52 μm
# Epoch 180 | Total: 3378.2610 | Coord: 3377.5920 | Contrast: 6.6883 | MSE: 3187.44 | MeanDist: 73.07 μm
# Epoch 183 | Total: 3324.5767 | Coord: 3323.9065 | Contrast: 6.7007 | MSE: 3181.40 | MeanDist: 72.80 μm
# Epoch 186 | Total: 3397.1536 | Coord: 3396.4834 | Contrast: 6.7024 | MSE: 3173.34 | MeanDist: 72.99 μm
# Epoch 189 | Total: 3336.4626 | Coord: 3335.7932 | Contrast: 6.6953 | MSE: 3166.93 | MeanDist: 72.96 μm
# Epoch 192 | Total: 3353.4907 | Coord: 3352.8208 | Contrast: 6.6996 | MSE: 3160.46 | MeanDist: 72.39 μm
# Epoch 195 | Total: 3321.5205 | Coord: 3320.8525 | Contrast: 6.6785 | MSE: 3149.23 | MeanDist: 72.41 μm
# Epoch 198 | Total: 3414.7666 | Coord: 3414.0972 | Contrast: 6.6942 | MSE: 3143.51 | MeanDist: 72.64 μm
# Epoch 201 | Total: 3456.2346 | Coord: 3455.5654 | Contrast: 6.6916 | MSE: 3135.00 | MeanDist: 71.94 μm
# Epoch 204 | Total: 3302.2756 | Coord: 3301.6074 | Contrast: 6.6814 | MSE: 3124.81 | MeanDist: 72.16 μm
# Epoch 207 | Total: 3409.8176 | Coord: 3409.1489 | Contrast: 6.6860 | MSE: 3116.80 | MeanDist: 71.98 μm
# Epoch 210 | Total: 3398.5938 | Coord: 3397.9236 | Contrast: 6.7021 | MSE: 3108.35 | MeanDist: 71.74 μm
# Epoch 213 | Total: 3384.3411 | Coord: 3383.6724 | Contrast: 6.6871 | MSE: 3103.87 | MeanDist: 71.96 μm
# Epoch 216 | Total: 3256.7104 | Coord: 3256.0425 | Contrast: 6.6788 | MSE: 3091.00 | MeanDist: 71.56 μm
# Epoch 219 | Total: 3360.6919 | Coord: 3360.0225 | Contrast: 6.6953 | MSE: 3083.04 | MeanDist: 71.12 μm
# Epoch 222 | Total: 3281.6045 | Coord: 3280.9355 | Contrast: 6.6899 | MSE: 3076.86 | MeanDist: 71.55 μm
# Epoch 225 | Total: 3354.0767 | Coord: 3353.4077 | Contrast: 6.6890 | MSE: 3062.92 | MeanDist: 71.01 μm
# Epoch 228 | Total: 3276.7173 | Coord: 3276.0481 | Contrast: 6.6915 | MSE: 3055.16 | MeanDist: 70.72 μm
# Epoch 231 | Total: 3265.5864 | Coord: 3264.9185 | Contrast: 6.6794 | MSE: 3051.96 | MeanDist: 71.12 μm
# Epoch 234 | Total: 3116.2200 | Coord: 3115.5515 | Contrast: 6.6857 | MSE: 3038.11 | MeanDist: 70.55 μm
# Epoch 237 | Total: 3173.3630 | Coord: 3172.6956 | Contrast: 6.6743 | MSE: 3029.61 | MeanDist: 70.23 μm
# Epoch 240 | Total: 3252.7268 | Coord: 3252.0598 | Contrast: 6.6694 | MSE: 3020.88 | MeanDist: 70.42 μm
# Epoch 243 | Total: 3177.4993 | Coord: 3176.8318 | Contrast: 6.6758 | MSE: 3012.68 | MeanDist: 69.96 μm
# Epoch 246 | Total: 3429.2788 | Coord: 3428.6106 | Contrast: 6.6809 | MSE: 3016.16 | MeanDist: 70.61 μm
# Epoch 249 | Total: 3153.4082 | Coord: 3152.7390 | Contrast: 6.6912 | MSE: 2997.31 | MeanDist: 69.93 μm
# Epoch 252 | Total: 3215.4736 | Coord: 3214.8057 | Contrast: 6.6807 | MSE: 2990.43 | MeanDist: 69.34 μm
# Epoch 255 | Total: 3265.5105 | Coord: 3264.8428 | Contrast: 6.6772 | MSE: 2984.16 | MeanDist: 69.84 μm
# Epoch 258 | Total: 3212.8005 | Coord: 3212.1304 | Contrast: 6.7017 | MSE: 2973.70 | MeanDist: 69.29 μm
# Epoch 261 | Total: 3097.4397 | Coord: 3096.7737 | Contrast: 6.6614 | MSE: 2971.90 | MeanDist: 68.95 μm
# Epoch 264 | Total: 3114.4050 | Coord: 3113.7358 | Contrast: 6.6917 | MSE: 2966.29 | MeanDist: 69.65 μm
# Epoch 267 | Total: 3337.0806 | Coord: 3336.4114 | Contrast: 6.6924 | MSE: 2947.87 | MeanDist: 68.92 μm
# Epoch 270 | Total: 3250.8396 | Coord: 3250.1726 | Contrast: 6.6709 | MSE: 2941.26 | MeanDist: 68.56 μm
# Epoch 273 | Total: 3243.5437 | Coord: 3242.8762 | Contrast: 6.6749 | MSE: 2946.12 | MeanDist: 69.39 μm
# Epoch 276 | Total: 3217.9460 | Coord: 3217.2786 | Contrast: 6.6759 | MSE: 2923.62 | MeanDist: 68.66 μm
# Epoch 279 | Total: 3150.7546 | Coord: 3150.0891 | Contrast: 6.6549 | MSE: 2922.39 | MeanDist: 67.69 μm
# Epoch 282 | Total: 3087.5352 | Coord: 3086.8667 | Contrast: 6.6851 | MSE: 2917.75 | MeanDist: 68.80 μm
# Epoch 285 | Total: 3301.2483 | Coord: 3300.5806 | Contrast: 6.6761 | MSE: 2898.96 | MeanDist: 67.85 μm
# Epoch 288 | Total: 2975.0903 | Coord: 2974.4233 | Contrast: 6.6691 | MSE: 2890.89 | MeanDist: 67.65 μm
# Epoch 291 | Total: 3079.7803 | Coord: 3079.1145 | Contrast: 6.6579 | MSE: 2887.70 | MeanDist: 68.13 μm
# Epoch 294 | Total: 3188.3467 | Coord: 3187.6816 | Contrast: 6.6511 | MSE: 2874.24 | MeanDist: 67.63 μm
# Epoch 297 | Total: 3001.2097 | Coord: 3000.5430 | Contrast: 6.6664 | MSE: 2873.86 | MeanDist: 66.98 μm
# Epoch 300 | Total: 3047.5317 | Coord: 3046.8657 | Contrast: 6.6612 | MSE: 2863.34 | MeanDist: 67.56 μm
# Epoch 303 | Total: 3057.6155 | Coord: 3056.9470 | Contrast: 6.6837 | MSE: 2860.83 | MeanDist: 67.72 μm
# Epoch 306 | Total: 2988.2766 | Coord: 2987.6113 | Contrast: 6.6521 | MSE: 2840.07 | MeanDist: 66.82 μm
# Epoch 309 | Total: 3104.8611 | Coord: 3104.1951 | Contrast: 6.6602 | MSE: 2832.19 | MeanDist: 66.78 μm
# Epoch 312 | Total: 3046.7937 | Coord: 3046.1260 | Contrast: 6.6762 | MSE: 2825.27 | MeanDist: 66.65 μm
# Epoch 315 | Total: 3085.9062 | Coord: 3085.2397 | Contrast: 6.6641 | MSE: 2817.65 | MeanDist: 66.37 μm
# Epoch 318 | Total: 2995.8494 | Coord: 2995.1836 | Contrast: 6.6588 | MSE: 2820.31 | MeanDist: 66.96 μm
# Epoch 321 | Total: 3105.4580 | Coord: 3104.7932 | Contrast: 6.6488 | MSE: 2804.71 | MeanDist: 66.16 μm
# Epoch 324 | Total: 3026.5693 | Coord: 3025.9038 | Contrast: 6.6551 | MSE: 2805.00 | MeanDist: 65.75 μm
# Epoch 327 | Total: 3117.7981 | Coord: 3117.1311 | Contrast: 6.6706 | MSE: 2811.04 | MeanDist: 66.77 μm
# Epoch 330 | Total: 2975.3232 | Coord: 2974.6587 | Contrast: 6.6451 | MSE: 2792.01 | MeanDist: 66.20 μm
# Epoch 333 | Total: 3036.9514 | Coord: 3036.2866 | Contrast: 6.6471 | MSE: 2790.51 | MeanDist: 65.53 μm
# Epoch 336 | Total: 3035.7502 | Coord: 3035.0857 | Contrast: 6.6450 | MSE: 2783.60 | MeanDist: 66.15 μm
# Epoch 339 | Total: 3019.6841 | Coord: 3019.0200 | Contrast: 6.6408 | MSE: 2774.88 | MeanDist: 65.89 μm
# Epoch 342 | Total: 3046.8955 | Coord: 3046.2319 | Contrast: 6.6348 | MSE: 2767.64 | MeanDist: 65.77 μm
# Epoch 345 | Total: 2922.4897 | Coord: 2921.8250 | Contrast: 6.6475 | MSE: 2759.17 | MeanDist: 65.20 μm
# Epoch 348 | Total: 3012.7703 | Coord: 3012.1067 | Contrast: 6.6354 | MSE: 2753.10 | MeanDist: 65.20 μm
# Epoch 351 | Total: 3079.2073 | Coord: 3078.5417 | Contrast: 6.6555 | MSE: 2748.84 | MeanDist: 65.13 μm
# Epoch 354 | Total: 2929.1072 | Coord: 2928.4426 | Contrast: 6.6457 | MSE: 2744.34 | MeanDist: 65.24 μm
# Epoch 357 | Total: 2925.4160 | Coord: 2924.7515 | Contrast: 6.6455 | MSE: 2738.30 | MeanDist: 64.85 μm
# Epoch 360 | Total: 2878.7253 | Coord: 2878.0586 | Contrast: 6.6676 | MSE: 2730.75 | MeanDist: 64.90 μm
# Epoch 363 | Total: 2979.7363 | Coord: 2979.0720 | Contrast: 6.6420 | MSE: 2728.39 | MeanDist: 64.42 μm
# Epoch 366 | Total: 2974.2148 | Coord: 2973.5500 | Contrast: 6.6480 | MSE: 2726.70 | MeanDist: 65.26 μm
# Epoch 369 | Total: 3165.4355 | Coord: 3164.7710 | Contrast: 6.6461 | MSE: 2716.83 | MeanDist: 64.36 μm
# Epoch 372 | Total: 2919.1462 | Coord: 2918.4817 | Contrast: 6.6447 | MSE: 2718.35 | MeanDist: 65.04 μm
# Epoch 375 | Total: 2942.5784 | Coord: 2941.9146 | Contrast: 6.6394 | MSE: 2710.44 | MeanDist: 64.42 μm
# Epoch 378 | Total: 3184.9958 | Coord: 3184.3333 | Contrast: 6.6267 | MSE: 2717.24 | MeanDist: 65.12 μm
# Epoch 381 | Total: 3035.1003 | Coord: 3034.4351 | Contrast: 6.6522 | MSE: 2709.03 | MeanDist: 64.12 μm
# Epoch 384 | Total: 2968.8848 | Coord: 2968.2219 | Contrast: 6.6279 | MSE: 2708.82 | MeanDist: 64.87 μm
# Epoch 387 | Total: 2855.9570 | Coord: 2855.2932 | Contrast: 6.6382 | MSE: 2697.90 | MeanDist: 64.31 μm
# Epoch 390 | Total: 2905.9595 | Coord: 2905.2954 | Contrast: 6.6403 | MSE: 2692.74 | MeanDist: 64.00 μm
# Epoch 393 | Total: 3066.3096 | Coord: 3065.6458 | Contrast: 6.6391 | MSE: 2728.92 | MeanDist: 65.68 μm
# Epoch 396 | Total: 2886.7661 | Coord: 2886.1003 | Contrast: 6.6568 | MSE: 2702.12 | MeanDist: 63.29 μm
# Epoch 399 | Total: 2906.5513 | Coord: 2905.8857 | Contrast: 6.6551 | MSE: 2677.93 | MeanDist: 63.83 μm
# Epoch 402 | Total: 2940.7568 | Coord: 2940.0938 | Contrast: 6.6313 | MSE: 2694.64 | MeanDist: 64.81 μm
# Epoch 405 | Total: 2865.7688 | Coord: 2865.1050 | Contrast: 6.6391 | MSE: 2674.26 | MeanDist: 63.47 μm
# Epoch 408 | Total: 2995.6729 | Coord: 2995.0098 | Contrast: 6.6313 | MSE: 2672.11 | MeanDist: 63.98 μm
# Epoch 411 | Total: 3019.4380 | Coord: 3018.7715 | Contrast: 6.6648 | MSE: 2681.01 | MeanDist: 64.57 μm
# Epoch 414 | Total: 2767.6858 | Coord: 2767.0239 | Contrast: 6.6194 | MSE: 2672.28 | MeanDist: 63.11 μm
# Epoch 417 | Total: 2918.9541 | Coord: 2918.2881 | Contrast: 6.6595 | MSE: 2661.50 | MeanDist: 63.83 μm
# Epoch 420 | Total: 2907.6726 | Coord: 2907.0085 | Contrast: 6.6396 | MSE: 2665.31 | MeanDist: 64.15 μm
# Epoch 423 | Total: 2825.0002 | Coord: 2824.3367 | Contrast: 6.6349 | MSE: 2681.47 | MeanDist: 62.67 μm
# Epoch 426 | Total: 2840.4438 | Coord: 2839.7800 | Contrast: 6.6388 | MSE: 2669.36 | MeanDist: 64.36 μm
# Epoch 429 | Total: 2833.5518 | Coord: 2832.8877 | Contrast: 6.6410 | MSE: 2652.67 | MeanDist: 63.31 μm
# Epoch 432 | Total: 2815.1343 | Coord: 2814.4692 | Contrast: 6.6496 | MSE: 2640.21 | MeanDist: 63.16 μm
# Epoch 435 | Total: 2907.0852 | Coord: 2906.4202 | Contrast: 6.6512 | MSE: 2644.16 | MeanDist: 63.85 μm
# Epoch 438 | Total: 2943.9785 | Coord: 2943.3142 | Contrast: 6.6423 | MSE: 2632.85 | MeanDist: 63.34 μm
# Epoch 441 | Total: 2840.7014 | Coord: 2840.0381 | Contrast: 6.6330 | MSE: 2631.33 | MeanDist: 62.61 μm
# Epoch 444 | Total: 2842.9595 | Coord: 2842.2952 | Contrast: 6.6435 | MSE: 2634.14 | MeanDist: 63.66 μm
# Epoch 447 | Total: 2839.4612 | Coord: 2838.7971 | Contrast: 6.6408 | MSE: 2624.61 | MeanDist: 63.18 μm
# Epoch 450 | Total: 2726.9893 | Coord: 2726.3286 | Contrast: 6.6076 | MSE: 2640.93 | MeanDist: 62.15 μm
# Epoch 453 | Total: 2926.6335 | Coord: 2925.9697 | Contrast: 6.6378 | MSE: 2640.16 | MeanDist: 63.90 μm
# Epoch 456 | Total: 2779.9788 | Coord: 2779.3157 | Contrast: 6.6304 | MSE: 2619.02 | MeanDist: 63.28 μm
# Epoch 459 | Total: 3005.0923 | Coord: 3004.4299 | Contrast: 6.6247 | MSE: 2610.03 | MeanDist: 62.47 μm
# Epoch 462 | Total: 2992.1548 | Coord: 2991.4929 | Contrast: 6.6187 | MSE: 2618.14 | MeanDist: 63.39 μm
# Epoch 465 | Total: 2790.7107 | Coord: 2790.0486 | Contrast: 6.6219 | MSE: 2604.48 | MeanDist: 62.47 μm
# Epoch 468 | Total: 2896.0627 | Coord: 2895.4004 | Contrast: 6.6245 | MSE: 2597.80 | MeanDist: 62.54 μm
# Epoch 471 | Total: 2914.6406 | Coord: 2913.9785 | Contrast: 6.6210 | MSE: 2604.96 | MeanDist: 63.03 μm
# Epoch 474 | Total: 2772.8149 | Coord: 2772.1528 | Contrast: 6.6210 | MSE: 2601.18 | MeanDist: 62.24 μm
# Epoch 477 | Total: 2866.4365 | Coord: 2865.7739 | Contrast: 6.6251 | MSE: 2595.70 | MeanDist: 62.57 μm
# Epoch 480 | Total: 3131.3413 | Coord: 3130.6790 | Contrast: 6.6241 | MSE: 2597.19 | MeanDist: 62.89 μm
# Epoch 483 | Total: 2866.2075 | Coord: 2865.5461 | Contrast: 6.6137 | MSE: 2586.72 | MeanDist: 62.20 μm
# Epoch 486 | Total: 2874.9878 | Coord: 2874.3242 | Contrast: 6.6356 | MSE: 2607.97 | MeanDist: 63.40 μm
# Epoch 489 | Total: 2787.3123 | Coord: 2786.6506 | Contrast: 6.6167 | MSE: 2596.85 | MeanDist: 61.54 μm
# Epoch 492 | Total: 2952.1536 | Coord: 2951.4924 | Contrast: 6.6106 | MSE: 2612.95 | MeanDist: 63.55 μm
# Epoch 495 | Total: 2843.4258 | Coord: 2842.7649 | Contrast: 6.6088 | MSE: 2585.77 | MeanDist: 62.30 μm
# Epoch 498 | Total: 2839.7834 | Coord: 2839.1201 | Contrast: 6.6331 | MSE: 2580.00 | MeanDist: 61.96 μm
# Epoch 499 | Total: 2840.0903 | Coord: 2839.4292 | Contrast: 6.6123 | MSE: 2583.63 | MeanDist: 62.53 μm
# Training finished in 363.4s

# %% [markdown]
# ## Evaluate Contrastive Learning Results
#
# Let's evaluate our model's performance on the coordinate prediction task.

# %%
# Evaluate the contrastive model
results = evaluate_contrastive_model(contrastive_model, data)

# Print results
print("COORDINATE PREDICTION RESULTS:")
print(f"Mean Squared Error: {results['mse']:.4f}")
print(f"Mean Absolute Error: {results['mae']:.4f}")
print(f"Mean Distance Error: {results['mean_distance_error']:.2f} μm")
print(f"Median Distance Error: {results['median_distance_error']:.2f} μm")
print(f"X-coordinate correlation: {results['correlation_x']:.4f}")
print(f"Y-coordinate correlation: {results['correlation_y']:.4f}")

# Visualize predictions
def visualize_predictions(data, model):
    model.eval()
    with torch.no_grad():
        pred_coords = model(data)
    
    # Get coordinates and predictions
    true_coords = data.target_coords.numpy()
    pred_coords_np = pred_coords.numpy()
    
    visible_mask = data.visible_mask.numpy()
    hidden_mask = data.hidden_mask.numpy()
    
    plt.figure(figsize=(10, 8))
    
    # Plot visible nodes
    plt.scatter(true_coords[visible_mask, 0], true_coords[visible_mask, 1], 
               c='blue', alpha=0.6, s=20, label='Visible nodes')
    
    # Plot true hidden nodes
    plt.scatter(true_coords[hidden_mask, 0], true_coords[hidden_mask, 1], 
               c='red', alpha=0.8, s=20, label='True hidden')
    
    # Plot predicted hidden nodes
    plt.scatter(pred_coords_np[hidden_mask, 0], pred_coords_np[hidden_mask, 1], 
               c='orange', alpha=0.8, s=20, label='Predicted hidden')
    
    # Draw error lines
    for i in np.where(hidden_mask)[0]:
        plt.plot([true_coords[i, 0], pred_coords_np[i, 0]], 
                [true_coords[i, 1], pred_coords_np[i, 1]], 
                'r-', alpha=0.3, linewidth=0.5)
    
    plt.title('Contrastive GCN Predictions')
    plt.legend()
    plt.axis('equal')
    plt.show()

# Visualize predictions
visualize_predictions(data, contrastive_model)
# Out:
# COORDINATE PREDICTION RESULTS:
# Mean Squared Error: 2583.6260
# Mean Absolute Error: 41.0392
# Mean Distance Error: 62.53 μm
# Median Distance Error: 58.86 μm
# X-coordinate correlation: 0.6151
# Y-coordinate correlation: 0.6727

# %% [markdown]
# ## Notes for how to possibly proceed
#
# above, We have applied a nuclei coordinate prediction task.
#
# Some directions for further exploration:
#
# 1. **Augmentation strategies**: Experiment with different graph augmentations like subgraph sampling, edge perturbation, and feature normalization.
#
# 2. **Projection head design**: Try different architectures for the projection head used in contrastive learning.
#
# 3. **Contrastive loss variants**: Implement other contrastive objectives like BYOL, MoCo, or SimCLR.
#
# 4. **Nuclei clustering**: Use the learned embeddings to cluster nuclei and identify regions with similar topological properties.

# %%
#example of analyzing learned embeddings
def analyze_embeddings(model, data):
    model.eval()
    with torch.no_grad():
        _, embeddings = model(data, return_embeddings=True)
    
    #numpy for analysis
    embeddings_np = embeddings.numpy()
    
    # Perform dimensionality reduction for visualization
    from sklearn.decomposition import PCA
    from sklearn.manifold import TSNE
    
    # PCA
    pca = PCA(n_components=2)
    embeddings_pca = pca.fit_transform(embeddings_np)
    
    # t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    embeddings_tsne = tsne.fit_transform(embeddings_np)
    
    # Visualize embeddings colored by spatial position
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # For color, use original spatial positions
    coords = data.target_coords.numpy()
    
    # PCA plot
    scatter1 = ax1.scatter(embeddings_pca[:, 0], embeddings_pca[:, 1], 
                          c=coords[:, 0], cmap='viridis', alpha=0.7, s=5)
    ax1.set_title('PCA of Node Embeddings\nColored by X-coordinate')
    ax1.set_xlabel('PC1')
    ax1.set_ylabel('PC2')
    plt.colorbar(scatter1, ax=ax1, label='X-coordinate')
    
    # t-SNE plot
    scatter2 = ax2.scatter(embeddings_tsne[:, 0], embeddings_tsne[:, 1], 
                          c=coords[:, 1], cmap='plasma', alpha=0.7, s=5)
    ax2.set_title('t-SNE of Node Embeddings\nColored by Y-coordinate')
    ax2.set_xlabel('t-SNE 1')
    ax2.set_ylabel('t-SNE 2')
    plt.colorbar(scatter2, ax=ax2, label='Y-coordinate')
    
    plt.tight_layout()
    plt.show()

analyze_embeddings(contrastive_model, data)
# Out:
# Analyzing learned embeddings...
# To get better results, run the full training in main_contrastive.py
# python main_contrastive.py
