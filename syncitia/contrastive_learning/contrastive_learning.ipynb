# %% [markdown]
# # Graph Contrastive Learning for Nuclei Coordinate Prediction
#
# Here I try to show how we can apply contrastive learning techniques to improve our graph neural network's ability to predict nuclei coordinates in syncytial tissue. Graph contrastive learning helps the model learn more robust representations by creating multiple augmented views of the graph data. This way we might be able to uncover topological patterns in our data. This notebook is also just a contained version of the rest of the directory, where you can run the python code

# %%
import sys
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from torch_geometric.utils import to_networkx

#parent directory to path for importing local modules
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(''))))
sys.path.append('..')  #parent directory
sys.path.append('../GCN')  #GCN directory for gcn_layer

from data_utils import load_data, build_graph, create_coordinate_prediction_data
from contrastive_gcn import ContrastiveGCN
from contrastive_utils import train_contrastive_model, evaluate_contrastive_model, create_graph_views

# %% [markdown]
# ## Load and prepare data
#
# let's load our nuclei coordinates and build a Delaunay triangulation graph.

# %%
coordinates = load_data('../nuclei-coordinates.csv')  
print(f"Loaded {len(coordinates)} nuclei")

#building the actual graph
G, _ = build_graph(coordinates) #build_graph has two return values, so we discard the second with _
print(f"Graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# Create coordinate prediction data
print("---Creating coordinate prediction task-----")
data = create_coordinate_prediction_data(coordinates, G, missing_fraction=0.25)

print("--Final Overview--")
print(f"Total nodes: {data.x.shape[0]}")
print(f"Visible nodes: {data.visible_mask.sum().item()}")
print(f"Hidden nodes: {data.hidden_mask.sum().item()}")
print(f"Edges: {data.edge_index.shape[1]}")
print(f"Node features: {data.x.shape[1]} dimensions")
# Out:
# Loaded 3340 nuclei
# Graph: 3340 nodes, 9992 edges
# ---Creating coordinate prediction task-----
# Hiding 1000 nodes (29.9%) in 5 clusters
# Keeping 2340 nodes visible for training
# --Final Overview--
# Total nodes: 3340
# Visible nodes: 2340
# Hidden nodes: 1000
# Edges: 19984
# Node features: 6 dimensions

# %% [markdown]
# ## Visualize graph augmentations
#
# Graph contrastive learning relies on creating different "views" of the same graph through augmentations. now let us visualize what these look like.

# %%
def visualize_graph_views(data, edge_dropout=0.3, feature_mask=0.3):
    """Visualize different augmented views of the graph"""
    # Create two augmented views
    view1, view2 = create_graph_views(data, edge_dropout_prob=edge_dropout, feature_mask_prob=feature_mask)
    
    # Convert to NetworkX for visualization
    G_original = to_networkx(data, to_undirected=True)
    G_view1 = to_networkx(view1, to_undirected=True)
    G_view2 = to_networkx(view2, to_undirected=True)
    
    # Calculate edge differences
    original_edges = set(G_original.edges())
    view1_edges = set(G_view1.edges())
    view2_edges = set(G_view2.edges())
    
    dropped_edges1 = original_edges - view1_edges
    dropped_edges2 = original_edges - view2_edges
    
    # Count differences
    print(f"Original graph: {len(original_edges)} edges")
    print(f"View 1: {len(view1_edges)} edges ({len(dropped_edges1)} dropped)")
    print(f"View 2: {len(view2_edges)} edges ({len(dropped_edges2)} dropped)")
    
    # Extract a small subgraph for visualization (100 nodes)
    nodes_to_vis = list(range(100))
    
    sub_original = G_original.subgraph(nodes_to_vis)
    sub_view1 = G_view1.subgraph(nodes_to_vis)
    sub_view2 = G_view2.subgraph(nodes_to_vis)
    
    # Plot
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    nx.draw_networkx(sub_original, node_size=30, with_labels=False)
    plt.title(f"Original Graph\n{len(sub_original.edges())} edges")
    
    plt.subplot(1, 3, 2)
    nx.draw_networkx(sub_view1, node_size=30, with_labels=False)
    plt.title(f"Augmented View 1\n{len(sub_view1.edges())} edges")
    
    plt.subplot(1, 3, 3)
    nx.draw_networkx(sub_view2, node_size=30, with_labels=False)
    plt.title(f"Augmented View 2\n{len(sub_view2.edges())} edges")
    
    plt.tight_layout()
    plt.show()

# Visualize graph augmentations
visualize_graph_views(data, edge_dropout=0.1, feature_mask=0.0)
# Out:
# Original graph: 9992 edges
# View 1: 8992 edges (1000 dropped)
# View 2: 8952 edges (1040 dropped)

# %% [markdown]
# ## 3. Initialize the contrastive learning model
#
# Our ContrastiveGCN model:
# - Uses higher-order GCN layers for feature extraction
# - Has a projection head for contrastive learning
# - Has a coordinate prediction head for the main task

# %%
# Initialize contrastive model
contrastive_model = ContrastiveGCN(
    in_channels=data.x.shape[1],  # Input feature dimensions
    hidden_channels=128,          # Hidden layer size
    proj_dim=64,                  # Projection dimension for contrastive learning
    tau=0.5                       # Temperature parameter
)

# Display model details
print(f"Contrastive model parameters: {sum(p.numel() for p in contrastive_model.parameters()):,}")
print(f"Model architecture:\n{contrastive_model}")
# Out:
# Contrastive model parameters: 19,622
# Model architecture:
# ContrastiveGCN(
#   (conv1): HigherOrderGCNLayer(
#     (conv): GCNConv(6, 128)
#   )
#   (conv2): HigherOrderGCNLayer(
#     (conv): GCNConv(128, 64)
#   )
#   (proj): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#   )
#   (coord_head): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=2, bias=True)
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ## 4. Contrastive Loss Function
#
# The contrastive loss encourages the model to learn similar representations for the same nodes in different augmented views of the graph.

# %%
# Demonstrate how contrastive loss works
def demo_contrastive_loss():
    # Create toy embeddings for demonstration
    batch_size = 10
    embedding_dim = 64
    
    # Same nodes, different views
    z1 = torch.randn(batch_size, embedding_dim)
    z2 = z1 + 0.1 * torch.randn(batch_size, embedding_dim)  # Similar to z1 (positive pairs)
    
    # Different nodes (negative pairs)
    z3 = torch.randn(batch_size, embedding_dim)
    
    # Calculate losses
    model = ContrastiveGCN(in_channels=data.x.shape[1], hidden_channels=64, proj_dim=embedding_dim)
    pos_loss = model.contrastive_loss(z1, z2)
    neg_loss = model.contrastive_loss(z1, z3)
    
    print(f"Contrastive loss between similar embeddings: {pos_loss.item():.4f}")
    print(f"Contrastive loss between different embeddings: {neg_loss.item():.4f}")
    print(f"Difference (should be positive): {neg_loss.item() - pos_loss.item():.4f}")
    
    # Visualize similarity matrices
    z1_norm = torch.nn.functional.normalize(z1, dim=1)
    z2_norm = torch.nn.functional.normalize(z2, dim=1)
    z3_norm = torch.nn.functional.normalize(z3, dim=1)
    
    sim_pos = torch.mm(z1_norm, z2_norm.t())
    sim_neg = torch.mm(z1_norm, z3_norm.t())
    
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.imshow(sim_pos.detach(), cmap='viridis')
    plt.colorbar()
    plt.title("Similarity Matrix: Positive Pairs\n(Diagonal should be bright)")
    
    plt.subplot(1, 2, 2)
    plt.imshow(sim_neg.detach(), cmap='viridis')
    plt.colorbar()
    plt.title("Similarity Matrix: Negative Pairs\n(Should be more random)")
    
    plt.tight_layout()
    plt.show()

# Demo the contrastive loss
demo_contrastive_loss()
# Out:
# Contrastive loss between similar embeddings: 0.8521
# Contrastive loss between different embeddings: 2.3611
# Difference (should be positive): 1.5090

# %% [markdown]
# ## 5. Training with Contrastive Learning
#
# Now let's train our model with the contrastive learning objective. We'll train for a limited number of epochs here, but for the full implementation you can run the `main_contrastive.py` script.

# %%
# Hot-reload utilities to pick up the latest function signatures
import importlib
import contrastive_utils as cu
cu = importlib.reload(cu)
from contrastive_utils import (
    train_contrastive_model,
    evaluate_contrastive_model,
    create_graph_views,
)
print("Reloaded contrastive_utils; functions re-imported.")
# Out:
# Reloaded contrastive_utils; functions re-imported.

# %%
# Reload GCN modules and recreate the model to pick up updated layer signatures
import importlib
import sys
sys.path.append('../GCN')  # Ensure GCN directory is in path

import gcn_layer as gl
import contrastive_gcn as cg

_ = importlib.reload(gl)
cg = importlib.reload(cg)
from contrastive_gcn import ContrastiveGCN

# Recreate model so its conv layers use the reloaded HigherOrderGCNLayer
contrastive_model = ContrastiveGCN(
    in_channels=data.x.shape[1],
    hidden_channels=128,
    proj_dim=64,
    tau=0.5,
)
print("Rebuilt contrastive_model with reloaded layers.")
# Out:
# Rebuilt contrastive_model with reloaded layers.

# %%
# Setup optimizer and loss function
optimizer = torch.optim.Adam(contrastive_model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = torch.nn.MSELoss()

# Compute adj_powers for the model (example: up to 3rd power)
def compute_adj_powers(G, max_power=3):
    import scipy.sparse as sp
    A = nx.to_scipy_sparse_array(G, format='csr')
    adj_powers = [torch.tensor((A ** k).toarray(), dtype=torch.float32) for k in range(1, max_power + 1)]
    return adj_powers

# Note: We don't need adj_powers for the current implementation

# Train for just 10 epochs for demonstration
print("Training contrastive model (demonstration with 10 epochs)...")

import time
start = time.time()
try:
    contrastive_model, train_losses = train_contrastive_model(
        contrastive_model,
        data,
        optimizer,
        criterion,
        num_epochs=200,
        lambda_contrast=0.1,
        edge_dropout_prob=0.1,      # milder augmentation for stability
        feature_mask_prob=0.1,      # milder feature masking
        log_every=1,                # print every epoch for visibility
    )
    print(f"Training finished in {time.time() - start:.1f}s")
except Exception as e:
    import traceback
    print("Training failed with error:\n", e)
    traceback.print_exc()
    raise

# Plot training loss
plt.figure(figsize=(8, 4))
plt.plot(train_losses, marker='o', linewidth=1)
plt.title("Contrastive Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# Training contrastive model (demonstration with 10 epochs)...
# Epoch 000 | Total: 12414.0020 | Coord: 12413.3018 | Contrast: 7.0021 | MSE: 11814.23 | MeanDist: 142.53 μm
# Epoch 000 | Total: 12414.0020 | Coord: 12413.3018 | Contrast: 7.0021 | MSE: 11814.23 | MeanDist: 142.53 μm
# Epoch 001 | Total: 12145.6006 | Coord: 12144.8701 | Contrast: 7.3065 | MSE: 11524.24 | MeanDist: 140.51 μm
# Epoch 001 | Total: 12145.6006 | Coord: 12144.8701 | Contrast: 7.3065 | MSE: 11524.24 | MeanDist: 140.51 μm
# Epoch 002 | Total: 11894.8350 | Coord: 11894.1211 | Contrast: 7.1426 | MSE: 11227.78 | MeanDist: 138.42 μm
# Epoch 002 | Total: 11894.8350 | Coord: 11894.1211 | Contrast: 7.1426 | MSE: 11227.78 | MeanDist: 138.42 μm
# Epoch 003 | Total: 11607.4648 | Coord: 11606.7549 | Contrast: 7.0989 | MSE: 10925.08 | MeanDist: 136.25 μm
# Epoch 003 | Total: 11607.4648 | Coord: 11606.7549 | Contrast: 7.0989 | MSE: 10925.08 | MeanDist: 136.25 μm
# Epoch 004 | Total: 11293.8906 | Coord: 11293.1787 | Contrast: 7.1160 | MSE: 10616.42 | MeanDist: 134.01 μm
# Epoch 004 | Total: 11293.8906 | Coord: 11293.1787 | Contrast: 7.1160 | MSE: 10616.42 | MeanDist: 134.01 μm
# Epoch 005 | Total: 11034.1963 | Coord: 11033.4883 | Contrast: 7.0850 | MSE: 10302.22 | MeanDist: 131.69 μm
# Epoch 005 | Total: 11034.1963 | Coord: 11033.4883 | Contrast: 7.0850 | MSE: 10302.22 | MeanDist: 131.69 μm
# Epoch 006 | Total: 10735.9609 | Coord: 10735.2549 | Contrast: 7.0584 | MSE: 9982.92 | MeanDist: 129.30 μm
# Epoch 006 | Total: 10735.9609 | Coord: 10735.2549 | Contrast: 7.0584 | MSE: 9982.92 | MeanDist: 129.30 μm
# Epoch 007 | Total: 10365.3877 | Coord: 10364.6836 | Contrast: 7.0454 | MSE: 9658.96 | MeanDist: 126.85 μm
# Epoch 007 | Total: 10365.3877 | Coord: 10364.6836 | Contrast: 7.0454 | MSE: 9658.96 | MeanDist: 126.85 μm
# Epoch 008 | Total: 10102.7070 | Coord: 10102.0020 | Contrast: 7.0490 | MSE: 9331.00 | MeanDist: 124.33 μm
# Epoch 008 | Total: 10102.7070 | Coord: 10102.0020 | Contrast: 7.0490 | MSE: 9331.00 | MeanDist: 124.33 μm
# Epoch 009 | Total: 9763.4834 | Coord: 9762.7783 | Contrast: 7.0462 | MSE: 8999.67 | MeanDist: 121.75 μm
# Epoch 009 | Total: 9763.4834 | Coord: 9762.7783 | Contrast: 7.0462 | MSE: 8999.67 | MeanDist: 121.75 μm
# Epoch 010 | Total: 9453.6250 | Coord: 9452.9209 | Contrast: 7.0424 | MSE: 8665.79 | MeanDist: 119.11 μm
# Epoch 010 | Total: 9453.6250 | Coord: 9452.9209 | Contrast: 7.0424 | MSE: 8665.79 | MeanDist: 119.11 μm
# Epoch 011 | Total: 9119.9785 | Coord: 9119.2764 | Contrast: 7.0253 | MSE: 8330.19 | MeanDist: 116.42 μm
# Epoch 011 | Total: 9119.9785 | Coord: 9119.2764 | Contrast: 7.0253 | MSE: 8330.19 | MeanDist: 116.42 μm
# Epoch 012 | Total: 8768.0059 | Coord: 8767.3018 | Contrast: 7.0389 | MSE: 7993.92 | MeanDist: 113.68 μm
# Epoch 012 | Total: 8768.0059 | Coord: 8767.3018 | Contrast: 7.0389 | MSE: 7993.92 | MeanDist: 113.68 μm
# Epoch 013 | Total: 8435.4014 | Coord: 8434.6973 | Contrast: 7.0384 | MSE: 7658.11 | MeanDist: 110.91 μm
# Epoch 013 | Total: 8435.4014 | Coord: 8434.6973 | Contrast: 7.0384 | MSE: 7658.11 | MeanDist: 110.91 μm
# Epoch 014 | Total: 8135.8286 | Coord: 8135.1265 | Contrast: 7.0232 | MSE: 7324.11 | MeanDist: 108.12 μm
# Epoch 014 | Total: 8135.8286 | Coord: 8135.1265 | Contrast: 7.0232 | MSE: 7324.11 | MeanDist: 108.12 μm
# Epoch 015 | Total: 7775.2476 | Coord: 7774.5459 | Contrast: 7.0178 | MSE: 6993.35 | MeanDist: 105.34 μm
# Epoch 015 | Total: 7775.2476 | Coord: 7774.5459 | Contrast: 7.0178 | MSE: 6993.35 | MeanDist: 105.34 μm
# Epoch 016 | Total: 7477.1943 | Coord: 7476.4937 | Contrast: 7.0053 | MSE: 6667.05 | MeanDist: 102.58 μm
# Epoch 016 | Total: 7477.1943 | Coord: 7476.4937 | Contrast: 7.0053 | MSE: 6667.05 | MeanDist: 102.58 μm
# Epoch 017 | Total: 7169.3638 | Coord: 7168.6626 | Contrast: 7.0128 | MSE: 6346.98 | MeanDist: 99.86 μm
# Epoch 017 | Total: 7169.3638 | Coord: 7168.6626 | Contrast: 7.0128 | MSE: 6346.98 | MeanDist: 99.86 μm
# Epoch 018 | Total: 6765.7642 | Coord: 6765.0630 | Contrast: 7.0102 | MSE: 6035.23 | MeanDist: 97.20 μm
# Epoch 018 | Total: 6765.7642 | Coord: 6765.0630 | Contrast: 7.0102 | MSE: 6035.23 | MeanDist: 97.20 μm
# Epoch 019 | Total: 6494.9209 | Coord: 6494.2183 | Contrast: 7.0270 | MSE: 5733.88 | MeanDist: 94.64 μm
# Epoch 019 | Total: 6494.9209 | Coord: 6494.2183 | Contrast: 7.0270 | MSE: 5733.88 | MeanDist: 94.64 μm
# Epoch 020 | Total: 6174.6055 | Coord: 6173.9033 | Contrast: 7.0217 | MSE: 5445.29 | MeanDist: 92.22 μm
# Epoch 020 | Total: 6174.6055 | Coord: 6173.9033 | Contrast: 7.0217 | MSE: 5445.29 | MeanDist: 92.22 μm
# Epoch 021 | Total: 5829.5400 | Coord: 5828.8389 | Contrast: 7.0111 | MSE: 5171.72 | MeanDist: 89.96 μm
# Epoch 021 | Total: 5829.5400 | Coord: 5828.8389 | Contrast: 7.0111 | MSE: 5171.72 | MeanDist: 89.96 μm
# Epoch 022 | Total: 5512.1973 | Coord: 5511.4961 | Contrast: 7.0102 | MSE: 4915.54 | MeanDist: 87.87 μm
# Epoch 022 | Total: 5512.1973 | Coord: 5511.4961 | Contrast: 7.0102 | MSE: 4915.54 | MeanDist: 87.87 μm
# Epoch 023 | Total: 5297.0986 | Coord: 5296.3965 | Contrast: 7.0231 | MSE: 4679.19 | MeanDist: 85.98 μm
# Epoch 023 | Total: 5297.0986 | Coord: 5296.3965 | Contrast: 7.0231 | MSE: 4679.19 | MeanDist: 85.98 μm
# Epoch 024 | Total: 5066.4272 | Coord: 5065.7256 | Contrast: 7.0153 | MSE: 4464.89 | MeanDist: 84.28 μm
# Epoch 024 | Total: 5066.4272 | Coord: 5065.7256 | Contrast: 7.0153 | MSE: 4464.89 | MeanDist: 84.28 μm
# Epoch 025 | Total: 4848.7119 | Coord: 4848.0098 | Contrast: 7.0209 | MSE: 4275.03 | MeanDist: 82.80 μm
# Epoch 025 | Total: 4848.7119 | Coord: 4848.0098 | Contrast: 7.0209 | MSE: 4275.03 | MeanDist: 82.80 μm
# Epoch 026 | Total: 4514.6729 | Coord: 4513.9722 | Contrast: 7.0073 | MSE: 4111.52 | MeanDist: 81.55 μm
# Epoch 026 | Total: 4514.6729 | Coord: 4513.9722 | Contrast: 7.0073 | MSE: 4111.52 | MeanDist: 81.55 μm
# Epoch 027 | Total: 4347.1392 | Coord: 4346.4395 | Contrast: 6.9995 | MSE: 3976.13 | MeanDist: 80.52 μm
# Epoch 027 | Total: 4347.1392 | Coord: 4346.4395 | Contrast: 6.9995 | MSE: 3976.13 | MeanDist: 80.52 μm
# Epoch 028 | Total: 4193.3877 | Coord: 4192.6885 | Contrast: 6.9906 | MSE: 3869.40 | MeanDist: 79.69 μm
# Epoch 028 | Total: 4193.3877 | Coord: 4192.6885 | Contrast: 6.9906 | MSE: 3869.40 | MeanDist: 79.69 μm
# Epoch 029 | Total: 3986.6384 | Coord: 3985.9387 | Contrast: 6.9976 | MSE: 3791.79 | MeanDist: 79.06 μm
# Epoch 029 | Total: 3986.6384 | Coord: 3985.9387 | Contrast: 6.9976 | MSE: 3791.79 | MeanDist: 79.06 μm
# Epoch 030 | Total: 3921.1597 | Coord: 3920.4587 | Contrast: 7.0083 | MSE: 3742.73 | MeanDist: 78.62 μm
# Epoch 030 | Total: 3921.1597 | Coord: 3920.4587 | Contrast: 7.0083 | MSE: 3742.73 | MeanDist: 78.62 μm
# Epoch 031 | Total: 3804.2827 | Coord: 3803.5828 | Contrast: 7.0004 | MSE: 3720.68 | MeanDist: 78.35 μm
# Epoch 031 | Total: 3804.2827 | Coord: 3803.5828 | Contrast: 7.0004 | MSE: 3720.68 | MeanDist: 78.35 μm
# Epoch 032 | Total: 3712.4827 | Coord: 3711.7827 | Contrast: 6.9985 | MSE: 3722.89 | MeanDist: 78.23 μm
# Epoch 032 | Total: 3712.4827 | Coord: 3711.7827 | Contrast: 6.9985 | MSE: 3722.89 | MeanDist: 78.23 μm
# Epoch 033 | Total: 3722.0415 | Coord: 3721.3411 | Contrast: 7.0036 | MSE: 3745.69 | MeanDist: 78.27 μm
# Epoch 033 | Total: 3722.0415 | Coord: 3721.3411 | Contrast: 7.0036 | MSE: 3745.69 | MeanDist: 78.27 μm
# Epoch 034 | Total: 3666.1284 | Coord: 3665.4285 | Contrast: 6.9991 | MSE: 3784.44 | MeanDist: 78.42 μm
# Epoch 034 | Total: 3666.1284 | Coord: 3665.4285 | Contrast: 6.9991 | MSE: 3784.44 | MeanDist: 78.42 μm
# Epoch 035 | Total: 3631.4290 | Coord: 3630.7297 | Contrast: 6.9927 | MSE: 3833.90 | MeanDist: 78.64 μm
# Epoch 035 | Total: 3631.4290 | Coord: 3630.7297 | Contrast: 6.9927 | MSE: 3833.90 | MeanDist: 78.64 μm
# Epoch 036 | Total: 3630.2539 | Coord: 3629.5542 | Contrast: 6.9959 | MSE: 3889.20 | MeanDist: 78.92 μm
# Epoch 036 | Total: 3630.2539 | Coord: 3629.5542 | Contrast: 6.9959 | MSE: 3889.20 | MeanDist: 78.92 μm
# Epoch 037 | Total: 3656.8894 | Coord: 3656.1887 | Contrast: 7.0060 | MSE: 3944.77 | MeanDist: 79.21 μm
# Epoch 037 | Total: 3656.8894 | Coord: 3656.1887 | Contrast: 7.0060 | MSE: 3944.77 | MeanDist: 79.21 μm
# Epoch 038 | Total: 3676.8877 | Coord: 3676.1877 | Contrast: 7.0005 | MSE: 3994.42 | MeanDist: 79.48 μm
# Epoch 038 | Total: 3676.8877 | Coord: 3676.1877 | Contrast: 7.0005 | MSE: 3994.42 | MeanDist: 79.48 μm
# Epoch 039 | Total: 3730.3250 | Coord: 3729.6252 | Contrast: 6.9965 | MSE: 4033.41 | MeanDist: 79.68 μm
# Epoch 039 | Total: 3730.3250 | Coord: 3729.6252 | Contrast: 6.9965 | MSE: 4033.41 | MeanDist: 79.68 μm
# Epoch 040 | Total: 3753.1541 | Coord: 3752.4553 | Contrast: 6.9864 | MSE: 4059.06 | MeanDist: 79.80 μm
# Epoch 040 | Total: 3753.1541 | Coord: 3752.4553 | Contrast: 6.9864 | MSE: 4059.06 | MeanDist: 79.80 μm
# Epoch 041 | Total: 3732.5530 | Coord: 3731.8542 | Contrast: 6.9872 | MSE: 4070.03 | MeanDist: 79.83 μm
# Epoch 041 | Total: 3732.5530 | Coord: 3731.8542 | Contrast: 6.9872 | MSE: 4070.03 | MeanDist: 79.83 μm
# Epoch 042 | Total: 3734.6208 | Coord: 3733.9229 | Contrast: 6.9809 | MSE: 4065.78 | MeanDist: 79.76 μm
# Epoch 042 | Total: 3734.6208 | Coord: 3733.9229 | Contrast: 6.9809 | MSE: 4065.78 | MeanDist: 79.76 μm
# Epoch 043 | Total: 3701.9795 | Coord: 3701.2808 | Contrast: 6.9861 | MSE: 4047.79 | MeanDist: 79.61 μm
# Epoch 043 | Total: 3701.9795 | Coord: 3701.2808 | Contrast: 6.9861 | MSE: 4047.79 | MeanDist: 79.61 μm
# Epoch 044 | Total: 3754.4727 | Coord: 3753.7739 | Contrast: 6.9872 | MSE: 4016.20 | MeanDist: 79.36 μm
# Epoch 044 | Total: 3754.4727 | Coord: 3753.7739 | Contrast: 6.9872 | MSE: 4016.20 | MeanDist: 79.36 μm
# Epoch 045 | Total: 3745.6650 | Coord: 3744.9673 | Contrast: 6.9770 | MSE: 3974.14 | MeanDist: 79.04 μm
# Epoch 045 | Total: 3745.6650 | Coord: 3744.9673 | Contrast: 6.9770 | MSE: 3974.14 | MeanDist: 79.04 μm
# Epoch 046 | Total: 3697.1660 | Coord: 3696.4668 | Contrast: 6.9922 | MSE: 3924.44 | MeanDist: 78.67 μm
# Epoch 046 | Total: 3697.1660 | Coord: 3696.4668 | Contrast: 6.9922 | MSE: 3924.44 | MeanDist: 78.67 μm
# Epoch 047 | Total: 3563.4670 | Coord: 3562.7693 | Contrast: 6.9781 | MSE: 3869.90 | MeanDist: 78.27 μm
# Epoch 047 | Total: 3563.4670 | Coord: 3562.7693 | Contrast: 6.9781 | MSE: 3869.90 | MeanDist: 78.27 μm
# Epoch 048 | Total: 3617.3486 | Coord: 3616.6504 | Contrast: 6.9830 | MSE: 3812.58 | MeanDist: 77.84 μm
# Epoch 048 | Total: 3617.3486 | Coord: 3616.6504 | Contrast: 6.9830 | MSE: 3812.58 | MeanDist: 77.84 μm
# Epoch 049 | Total: 3578.9077 | Coord: 3578.2109 | Contrast: 6.9671 | MSE: 3754.82 | MeanDist: 77.41 μm
# Epoch 049 | Total: 3578.9077 | Coord: 3578.2109 | Contrast: 6.9671 | MSE: 3754.82 | MeanDist: 77.41 μm
# Epoch 050 | Total: 3548.5315 | Coord: 3547.8342 | Contrast: 6.9731 | MSE: 3698.46 | MeanDist: 77.00 μm
# Epoch 050 | Total: 3548.5315 | Coord: 3547.8342 | Contrast: 6.9731 | MSE: 3698.46 | MeanDist: 77.00 μm
# Epoch 051 | Total: 3510.9661 | Coord: 3510.2681 | Contrast: 6.9808 | MSE: 3646.36 | MeanDist: 76.61 μm
# Epoch 051 | Total: 3510.9661 | Coord: 3510.2681 | Contrast: 6.9808 | MSE: 3646.36 | MeanDist: 76.61 μm
# Epoch 052 | Total: 3495.2495 | Coord: 3494.5532 | Contrast: 6.9622 | MSE: 3598.74 | MeanDist: 76.25 μm
# Epoch 052 | Total: 3495.2495 | Coord: 3494.5532 | Contrast: 6.9622 | MSE: 3598.74 | MeanDist: 76.25 μm
# Epoch 053 | Total: 3519.7095 | Coord: 3519.0127 | Contrast: 6.9678 | MSE: 3555.96 | MeanDist: 75.92 μm
# Epoch 053 | Total: 3519.7095 | Coord: 3519.0127 | Contrast: 6.9678 | MSE: 3555.96 | MeanDist: 75.92 μm
# Epoch 054 | Total: 3450.7109 | Coord: 3450.0139 | Contrast: 6.9700 | MSE: 3518.39 | MeanDist: 75.64 μm
# Epoch 054 | Total: 3450.7109 | Coord: 3450.0139 | Contrast: 6.9700 | MSE: 3518.39 | MeanDist: 75.64 μm
# Epoch 055 | Total: 3459.2612 | Coord: 3458.5662 | Contrast: 6.9517 | MSE: 3485.90 | MeanDist: 75.39 μm
# Epoch 055 | Total: 3459.2612 | Coord: 3458.5662 | Contrast: 6.9517 | MSE: 3485.90 | MeanDist: 75.39 μm
# Epoch 056 | Total: 3425.8035 | Coord: 3425.1064 | Contrast: 6.9709 | MSE: 3457.94 | MeanDist: 75.17 μm
# Epoch 056 | Total: 3425.8035 | Coord: 3425.1064 | Contrast: 6.9709 | MSE: 3457.94 | MeanDist: 75.17 μm
# Epoch 057 | Total: 3418.3064 | Coord: 3417.6113 | Contrast: 6.9507 | MSE: 3434.29 | MeanDist: 74.98 μm
# Epoch 057 | Total: 3418.3064 | Coord: 3417.6113 | Contrast: 6.9507 | MSE: 3434.29 | MeanDist: 74.98 μm
# Epoch 058 | Total: 3408.4971 | Coord: 3407.8022 | Contrast: 6.9476 | MSE: 3414.30 | MeanDist: 74.82 μm
# Epoch 058 | Total: 3408.4971 | Coord: 3407.8022 | Contrast: 6.9476 | MSE: 3414.30 | MeanDist: 74.82 μm
# Epoch 059 | Total: 3374.6257 | Coord: 3373.9321 | Contrast: 6.9359 | MSE: 3397.11 | MeanDist: 74.67 μm
# Epoch 059 | Total: 3374.6257 | Coord: 3373.9321 | Contrast: 6.9359 | MSE: 3397.11 | MeanDist: 74.67 μm
# Epoch 060 | Total: 3381.4919 | Coord: 3380.7969 | Contrast: 6.9508 | MSE: 3382.32 | MeanDist: 74.54 μm
# Epoch 060 | Total: 3381.4919 | Coord: 3380.7969 | Contrast: 6.9508 | MSE: 3382.32 | MeanDist: 74.54 μm
# Epoch 061 | Total: 3440.2505 | Coord: 3439.5564 | Contrast: 6.9399 | MSE: 3369.29 | MeanDist: 74.41 μm
# Epoch 061 | Total: 3440.2505 | Coord: 3439.5564 | Contrast: 6.9399 | MSE: 3369.29 | MeanDist: 74.41 μm
# Epoch 062 | Total: 3366.1982 | Coord: 3365.5051 | Contrast: 6.9318 | MSE: 3357.72 | MeanDist: 74.30 μm
# Epoch 062 | Total: 3366.1982 | Coord: 3365.5051 | Contrast: 6.9318 | MSE: 3357.72 | MeanDist: 74.30 μm
# Epoch 063 | Total: 3324.6216 | Coord: 3323.9277 | Contrast: 6.9381 | MSE: 3347.32 | MeanDist: 74.19 μm
# Epoch 063 | Total: 3324.6216 | Coord: 3323.9277 | Contrast: 6.9381 | MSE: 3347.32 | MeanDist: 74.19 μm
# Epoch 064 | Total: 3358.0981 | Coord: 3357.4050 | Contrast: 6.9311 | MSE: 3337.88 | MeanDist: 74.08 μm
# Epoch 064 | Total: 3358.0981 | Coord: 3357.4050 | Contrast: 6.9311 | MSE: 3337.88 | MeanDist: 74.08 μm
# Epoch 065 | Total: 3347.0745 | Coord: 3346.3796 | Contrast: 6.9475 | MSE: 3329.22 | MeanDist: 73.98 μm
# Epoch 065 | Total: 3347.0745 | Coord: 3346.3796 | Contrast: 6.9475 | MSE: 3329.22 | MeanDist: 73.98 μm
# Epoch 066 | Total: 3379.4382 | Coord: 3378.7441 | Contrast: 6.9402 | MSE: 3321.36 | MeanDist: 73.88 μm
# Epoch 066 | Total: 3379.4382 | Coord: 3378.7441 | Contrast: 6.9402 | MSE: 3321.36 | MeanDist: 73.88 μm
# Epoch 067 | Total: 3345.1667 | Coord: 3344.4739 | Contrast: 6.9279 | MSE: 3314.22 | MeanDist: 73.78 μm
# Epoch 067 | Total: 3345.1667 | Coord: 3344.4739 | Contrast: 6.9279 | MSE: 3314.22 | MeanDist: 73.78 μm
# Epoch 068 | Total: 3410.4980 | Coord: 3409.8059 | Contrast: 6.9206 | MSE: 3307.77 | MeanDist: 73.69 μm
# Epoch 068 | Total: 3410.4980 | Coord: 3409.8059 | Contrast: 6.9206 | MSE: 3307.77 | MeanDist: 73.69 μm
# Epoch 069 | Total: 3302.6965 | Coord: 3302.0046 | Contrast: 6.9191 | MSE: 3302.00 | MeanDist: 73.60 μm
# Epoch 069 | Total: 3302.6965 | Coord: 3302.0046 | Contrast: 6.9191 | MSE: 3302.00 | MeanDist: 73.60 μm
# Epoch 070 | Total: 3265.8525 | Coord: 3265.1599 | Contrast: 6.9272 | MSE: 3296.98 | MeanDist: 73.51 μm
# Epoch 070 | Total: 3265.8525 | Coord: 3265.1599 | Contrast: 6.9272 | MSE: 3296.98 | MeanDist: 73.51 μm
# Epoch 071 | Total: 3352.7612 | Coord: 3352.0691 | Contrast: 6.9216 | MSE: 3292.68 | MeanDist: 73.43 μm
# Epoch 071 | Total: 3352.7612 | Coord: 3352.0691 | Contrast: 6.9216 | MSE: 3292.68 | MeanDist: 73.43 μm
# Epoch 072 | Total: 3278.4448 | Coord: 3277.7542 | Contrast: 6.9056 | MSE: 3288.95 | MeanDist: 73.35 μm
# Epoch 072 | Total: 3278.4448 | Coord: 3277.7542 | Contrast: 6.9056 | MSE: 3288.95 | MeanDist: 73.35 μm
# Epoch 073 | Total: 3249.5540 | Coord: 3248.8625 | Contrast: 6.9148 | MSE: 3286.10 | MeanDist: 73.28 μm
# Epoch 073 | Total: 3249.5540 | Coord: 3248.8625 | Contrast: 6.9148 | MSE: 3286.10 | MeanDist: 73.28 μm
# Epoch 074 | Total: 3335.5315 | Coord: 3334.8401 | Contrast: 6.9136 | MSE: 3283.84 | MeanDist: 73.22 μm
# Epoch 074 | Total: 3335.5315 | Coord: 3334.8401 | Contrast: 6.9136 | MSE: 3283.84 | MeanDist: 73.22 μm
# Epoch 075 | Total: 3275.8621 | Coord: 3275.1704 | Contrast: 6.9170 | MSE: 3282.00 | MeanDist: 73.16 μm
# Epoch 075 | Total: 3275.8621 | Coord: 3275.1704 | Contrast: 6.9170 | MSE: 3282.00 | MeanDist: 73.16 μm
# Epoch 076 | Total: 3268.1492 | Coord: 3267.4580 | Contrast: 6.9107 | MSE: 3280.48 | MeanDist: 73.10 μm
# Epoch 076 | Total: 3268.1492 | Coord: 3267.4580 | Contrast: 6.9107 | MSE: 3280.48 | MeanDist: 73.10 μm
# Epoch 077 | Total: 3254.2991 | Coord: 3253.6091 | Contrast: 6.8989 | MSE: 3279.17 | MeanDist: 73.04 μm
# Epoch 077 | Total: 3254.2991 | Coord: 3253.6091 | Contrast: 6.8989 | MSE: 3279.17 | MeanDist: 73.04 μm
# Epoch 078 | Total: 3230.3652 | Coord: 3229.6750 | Contrast: 6.9028 | MSE: 3277.96 | MeanDist: 72.99 μm
# Epoch 078 | Total: 3230.3652 | Coord: 3229.6750 | Contrast: 6.9028 | MSE: 3277.96 | MeanDist: 72.99 μm
# Epoch 079 | Total: 3266.7703 | Coord: 3266.0791 | Contrast: 6.9105 | MSE: 3276.59 | MeanDist: 72.94 μm
# Epoch 079 | Total: 3266.7703 | Coord: 3266.0791 | Contrast: 6.9105 | MSE: 3276.59 | MeanDist: 72.94 μm
# Epoch 080 | Total: 3285.9385 | Coord: 3285.2493 | Contrast: 6.8913 | MSE: 3274.73 | MeanDist: 72.89 μm
# Epoch 080 | Total: 3285.9385 | Coord: 3285.2493 | Contrast: 6.8913 | MSE: 3274.73 | MeanDist: 72.89 μm
# Epoch 081 | Total: 3226.7905 | Coord: 3226.0999 | Contrast: 6.9057 | MSE: 3272.85 | MeanDist: 72.83 μm
# Epoch 081 | Total: 3226.7905 | Coord: 3226.0999 | Contrast: 6.9057 | MSE: 3272.85 | MeanDist: 72.83 μm
# Epoch 082 | Total: 3193.2461 | Coord: 3192.5569 | Contrast: 6.8929 | MSE: 3270.69 | MeanDist: 72.78 μm
# Epoch 082 | Total: 3193.2461 | Coord: 3192.5569 | Contrast: 6.8929 | MSE: 3270.69 | MeanDist: 72.78 μm
# Epoch 083 | Total: 3150.1333 | Coord: 3149.4434 | Contrast: 6.8996 | MSE: 3267.73 | MeanDist: 72.72 μm
# Epoch 083 | Total: 3150.1333 | Coord: 3149.4434 | Contrast: 6.8996 | MSE: 3267.73 | MeanDist: 72.72 μm
# Epoch 084 | Total: 3233.4197 | Coord: 3232.7302 | Contrast: 6.8945 | MSE: 3264.42 | MeanDist: 72.66 μm
# Epoch 084 | Total: 3233.4197 | Coord: 3232.7302 | Contrast: 6.8945 | MSE: 3264.42 | MeanDist: 72.66 μm
# Epoch 085 | Total: 3174.5439 | Coord: 3173.8547 | Contrast: 6.8928 | MSE: 3260.31 | MeanDist: 72.60 μm
# Epoch 085 | Total: 3174.5439 | Coord: 3173.8547 | Contrast: 6.8928 | MSE: 3260.31 | MeanDist: 72.60 μm
# Epoch 086 | Total: 3243.9290 | Coord: 3243.2393 | Contrast: 6.8980 | MSE: 3255.57 | MeanDist: 72.53 μm
# Epoch 086 | Total: 3243.9290 | Coord: 3243.2393 | Contrast: 6.8980 | MSE: 3255.57 | MeanDist: 72.53 μm
# Epoch 087 | Total: 3188.1738 | Coord: 3187.4846 | Contrast: 6.8924 | MSE: 3250.50 | MeanDist: 72.47 μm
# Epoch 087 | Total: 3188.1738 | Coord: 3187.4846 | Contrast: 6.8924 | MSE: 3250.50 | MeanDist: 72.47 μm
# Epoch 088 | Total: 3177.9561 | Coord: 3177.2673 | Contrast: 6.8864 | MSE: 3245.12 | MeanDist: 72.40 μm
# Epoch 088 | Total: 3177.9561 | Coord: 3177.2673 | Contrast: 6.8864 | MSE: 3245.12 | MeanDist: 72.40 μm
# Epoch 089 | Total: 3217.3330 | Coord: 3216.6433 | Contrast: 6.8965 | MSE: 3239.15 | MeanDist: 72.33 μm
# Epoch 089 | Total: 3217.3330 | Coord: 3216.6433 | Contrast: 6.8965 | MSE: 3239.15 | MeanDist: 72.33 μm
# Epoch 090 | Total: 3171.1777 | Coord: 3170.4895 | Contrast: 6.8812 | MSE: 3232.80 | MeanDist: 72.25 μm
# Epoch 090 | Total: 3171.1777 | Coord: 3170.4895 | Contrast: 6.8812 | MSE: 3232.80 | MeanDist: 72.25 μm
# Epoch 091 | Total: 3221.8264 | Coord: 3221.1372 | Contrast: 6.8910 | MSE: 3226.18 | MeanDist: 72.18 μm
# Epoch 091 | Total: 3221.8264 | Coord: 3221.1372 | Contrast: 6.8910 | MSE: 3226.18 | MeanDist: 72.18 μm
# Epoch 092 | Total: 3203.7747 | Coord: 3203.0864 | Contrast: 6.8817 | MSE: 3219.61 | MeanDist: 72.10 μm
# Epoch 092 | Total: 3203.7747 | Coord: 3203.0864 | Contrast: 6.8817 | MSE: 3219.61 | MeanDist: 72.10 μm
# Epoch 093 | Total: 3209.1060 | Coord: 3208.4175 | Contrast: 6.8837 | MSE: 3212.78 | MeanDist: 72.03 μm
# Epoch 093 | Total: 3209.1060 | Coord: 3208.4175 | Contrast: 6.8837 | MSE: 3212.78 | MeanDist: 72.03 μm
# Epoch 094 | Total: 3145.1572 | Coord: 3144.4690 | Contrast: 6.8824 | MSE: 3206.00 | MeanDist: 71.96 μm
# Epoch 094 | Total: 3145.1572 | Coord: 3144.4690 | Contrast: 6.8824 | MSE: 3206.00 | MeanDist: 71.96 μm
# Epoch 095 | Total: 3169.8928 | Coord: 3169.2041 | Contrast: 6.8860 | MSE: 3199.17 | MeanDist: 71.89 μm
# Epoch 095 | Total: 3169.8928 | Coord: 3169.2041 | Contrast: 6.8860 | MSE: 3199.17 | MeanDist: 71.89 μm
# Epoch 096 | Total: 3172.7168 | Coord: 3172.0286 | Contrast: 6.8832 | MSE: 3192.49 | MeanDist: 71.82 μm
# Epoch 096 | Total: 3172.7168 | Coord: 3172.0286 | Contrast: 6.8832 | MSE: 3192.49 | MeanDist: 71.82 μm
# Epoch 097 | Total: 3180.3401 | Coord: 3179.6526 | Contrast: 6.8751 | MSE: 3185.79 | MeanDist: 71.75 μm
# Epoch 097 | Total: 3180.3401 | Coord: 3179.6526 | Contrast: 6.8751 | MSE: 3185.79 | MeanDist: 71.75 μm
# Epoch 098 | Total: 3206.8318 | Coord: 3206.1450 | Contrast: 6.8679 | MSE: 3179.36 | MeanDist: 71.68 μm
# Epoch 098 | Total: 3206.8318 | Coord: 3206.1450 | Contrast: 6.8679 | MSE: 3179.36 | MeanDist: 71.68 μm
# Epoch 099 | Total: 3105.2056 | Coord: 3104.5183 | Contrast: 6.8715 | MSE: 3173.60 | MeanDist: 71.62 μm
# Epoch 099 | Total: 3105.2056 | Coord: 3104.5183 | Contrast: 6.8715 | MSE: 3173.60 | MeanDist: 71.62 μm
# Epoch 100 | Total: 3140.9084 | Coord: 3140.2224 | Contrast: 6.8609 | MSE: 3168.21 | MeanDist: 71.56 μm
# Epoch 100 | Total: 3140.9084 | Coord: 3140.2224 | Contrast: 6.8609 | MSE: 3168.21 | MeanDist: 71.56 μm
# Epoch 101 | Total: 3151.5322 | Coord: 3150.8440 | Contrast: 6.8834 | MSE: 3163.18 | MeanDist: 71.50 μm
# Epoch 101 | Total: 3151.5322 | Coord: 3150.8440 | Contrast: 6.8834 | MSE: 3163.18 | MeanDist: 71.50 μm
# Epoch 102 | Total: 3143.8296 | Coord: 3143.1428 | Contrast: 6.8665 | MSE: 3158.63 | MeanDist: 71.44 μm
# Epoch 102 | Total: 3143.8296 | Coord: 3143.1428 | Contrast: 6.8665 | MSE: 3158.63 | MeanDist: 71.44 μm
# Epoch 103 | Total: 3115.7732 | Coord: 3115.0857 | Contrast: 6.8749 | MSE: 3155.00 | MeanDist: 71.40 μm
# Epoch 103 | Total: 3115.7732 | Coord: 3115.0857 | Contrast: 6.8749 | MSE: 3155.00 | MeanDist: 71.40 μm
# Epoch 104 | Total: 3177.4609 | Coord: 3176.7732 | Contrast: 6.8763 | MSE: 3151.56 | MeanDist: 71.35 μm
# Epoch 104 | Total: 3177.4609 | Coord: 3176.7732 | Contrast: 6.8763 | MSE: 3151.56 | MeanDist: 71.35 μm
# Epoch 105 | Total: 3160.2732 | Coord: 3159.5872 | Contrast: 6.8593 | MSE: 3148.31 | MeanDist: 71.30 μm
# Epoch 105 | Total: 3160.2732 | Coord: 3159.5872 | Contrast: 6.8593 | MSE: 3148.31 | MeanDist: 71.30 μm
# Epoch 106 | Total: 3128.5818 | Coord: 3127.8945 | Contrast: 6.8717 | MSE: 3145.61 | MeanDist: 71.26 μm
# Epoch 106 | Total: 3128.5818 | Coord: 3127.8945 | Contrast: 6.8717 | MSE: 3145.61 | MeanDist: 71.26 μm
# Epoch 107 | Total: 3171.5071 | Coord: 3170.8203 | Contrast: 6.8680 | MSE: 3143.23 | MeanDist: 71.22 μm
# Epoch 107 | Total: 3171.5071 | Coord: 3170.8203 | Contrast: 6.8680 | MSE: 3143.23 | MeanDist: 71.22 μm
# Epoch 108 | Total: 3129.4800 | Coord: 3128.7930 | Contrast: 6.8706 | MSE: 3141.00 | MeanDist: 71.18 μm
# Epoch 108 | Total: 3129.4800 | Coord: 3128.7930 | Contrast: 6.8706 | MSE: 3141.00 | MeanDist: 71.18 μm
# Epoch 109 | Total: 3143.8474 | Coord: 3143.1614 | Contrast: 6.8599 | MSE: 3138.85 | MeanDist: 71.14 μm
# Epoch 109 | Total: 3143.8474 | Coord: 3143.1614 | Contrast: 6.8599 | MSE: 3138.85 | MeanDist: 71.14 μm
# Epoch 110 | Total: 3072.4641 | Coord: 3071.7776 | Contrast: 6.8652 | MSE: 3137.13 | MeanDist: 71.11 μm
# Epoch 110 | Total: 3072.4641 | Coord: 3071.7776 | Contrast: 6.8652 | MSE: 3137.13 | MeanDist: 71.11 μm
# Epoch 111 | Total: 3112.7705 | Coord: 3112.0852 | Contrast: 6.8527 | MSE: 3135.25 | MeanDist: 71.07 μm
# Epoch 111 | Total: 3112.7705 | Coord: 3112.0852 | Contrast: 6.8527 | MSE: 3135.25 | MeanDist: 71.07 μm
# Epoch 112 | Total: 3093.7859 | Coord: 3093.1006 | Contrast: 6.8524 | MSE: 3133.41 | MeanDist: 71.04 μm
# Epoch 112 | Total: 3093.7859 | Coord: 3093.1006 | Contrast: 6.8524 | MSE: 3133.41 | MeanDist: 71.04 μm
# Epoch 113 | Total: 3108.8047 | Coord: 3108.1194 | Contrast: 6.8531 | MSE: 3131.80 | MeanDist: 71.01 μm
# Epoch 113 | Total: 3108.8047 | Coord: 3108.1194 | Contrast: 6.8531 | MSE: 3131.80 | MeanDist: 71.01 μm
# Epoch 114 | Total: 3116.1099 | Coord: 3115.4246 | Contrast: 6.8527 | MSE: 3130.11 | MeanDist: 70.98 μm
# Epoch 114 | Total: 3116.1099 | Coord: 3115.4246 | Contrast: 6.8527 | MSE: 3130.11 | MeanDist: 70.98 μm
# Epoch 115 | Total: 3138.4006 | Coord: 3137.7158 | Contrast: 6.8482 | MSE: 3128.03 | MeanDist: 70.94 μm
# Epoch 115 | Total: 3138.4006 | Coord: 3137.7158 | Contrast: 6.8482 | MSE: 3128.03 | MeanDist: 70.94 μm
# Epoch 116 | Total: 3074.0771 | Coord: 3073.3921 | Contrast: 6.8512 | MSE: 3125.80 | MeanDist: 70.91 μm
# Epoch 116 | Total: 3074.0771 | Coord: 3073.3921 | Contrast: 6.8512 | MSE: 3125.80 | MeanDist: 70.91 μm
# Epoch 117 | Total: 3102.2434 | Coord: 3101.5588 | Contrast: 6.8452 | MSE: 3123.46 | MeanDist: 70.87 μm
# Epoch 117 | Total: 3102.2434 | Coord: 3101.5588 | Contrast: 6.8452 | MSE: 3123.46 | MeanDist: 70.87 μm
# Epoch 118 | Total: 3094.6626 | Coord: 3093.9780 | Contrast: 6.8448 | MSE: 3120.98 | MeanDist: 70.84 μm
# Epoch 118 | Total: 3094.6626 | Coord: 3093.9780 | Contrast: 6.8448 | MSE: 3120.98 | MeanDist: 70.84 μm
# Epoch 119 | Total: 3093.3647 | Coord: 3092.6807 | Contrast: 6.8411 | MSE: 3118.50 | MeanDist: 70.81 μm
# Epoch 119 | Total: 3093.3647 | Coord: 3092.6807 | Contrast: 6.8411 | MSE: 3118.50 | MeanDist: 70.81 μm
# Epoch 120 | Total: 3125.2058 | Coord: 3124.5208 | Contrast: 6.8508 | MSE: 3116.35 | MeanDist: 70.77 μm
# Epoch 120 | Total: 3125.2058 | Coord: 3124.5208 | Contrast: 6.8508 | MSE: 3116.35 | MeanDist: 70.77 μm
# Epoch 121 | Total: 3094.9988 | Coord: 3094.3145 | Contrast: 6.8443 | MSE: 3114.26 | MeanDist: 70.74 μm
# Epoch 121 | Total: 3094.9988 | Coord: 3094.3145 | Contrast: 6.8443 | MSE: 3114.26 | MeanDist: 70.74 μm
# Epoch 122 | Total: 3109.3496 | Coord: 3108.6653 | Contrast: 6.8426 | MSE: 3111.98 | MeanDist: 70.71 μm
# Epoch 122 | Total: 3109.3496 | Coord: 3108.6653 | Contrast: 6.8426 | MSE: 3111.98 | MeanDist: 70.71 μm
# Epoch 123 | Total: 3163.7766 | Coord: 3163.0930 | Contrast: 6.8369 | MSE: 3109.42 | MeanDist: 70.68 μm
# Epoch 123 | Total: 3163.7766 | Coord: 3163.0930 | Contrast: 6.8369 | MSE: 3109.42 | MeanDist: 70.68 μm
# Epoch 124 | Total: 3149.7942 | Coord: 3149.1104 | Contrast: 6.8394 | MSE: 3106.72 | MeanDist: 70.65 μm
# Epoch 124 | Total: 3149.7942 | Coord: 3149.1104 | Contrast: 6.8394 | MSE: 3106.72 | MeanDist: 70.65 μm
# Epoch 125 | Total: 3082.1030 | Coord: 3081.4192 | Contrast: 6.8376 | MSE: 3104.11 | MeanDist: 70.62 μm
# Epoch 125 | Total: 3082.1030 | Coord: 3081.4192 | Contrast: 6.8376 | MSE: 3104.11 | MeanDist: 70.62 μm
# Epoch 126 | Total: 3059.2427 | Coord: 3058.5601 | Contrast: 6.8256 | MSE: 3101.75 | MeanDist: 70.59 μm
# Epoch 126 | Total: 3059.2427 | Coord: 3058.5601 | Contrast: 6.8256 | MSE: 3101.75 | MeanDist: 70.59 μm
# Epoch 127 | Total: 3114.7954 | Coord: 3114.1113 | Contrast: 6.8400 | MSE: 3099.61 | MeanDist: 70.57 μm
# Epoch 127 | Total: 3114.7954 | Coord: 3114.1113 | Contrast: 6.8400 | MSE: 3099.61 | MeanDist: 70.57 μm
# Epoch 128 | Total: 3107.3486 | Coord: 3106.6658 | Contrast: 6.8274 | MSE: 3097.56 | MeanDist: 70.54 μm
# Epoch 128 | Total: 3107.3486 | Coord: 3106.6658 | Contrast: 6.8274 | MSE: 3097.56 | MeanDist: 70.54 μm
# Epoch 129 | Total: 3078.0007 | Coord: 3077.3186 | Contrast: 6.8222 | MSE: 3096.11 | MeanDist: 70.52 μm
# Epoch 129 | Total: 3078.0007 | Coord: 3077.3186 | Contrast: 6.8222 | MSE: 3096.11 | MeanDist: 70.52 μm
# Epoch 130 | Total: 3120.6423 | Coord: 3119.9600 | Contrast: 6.8242 | MSE: 3094.69 | MeanDist: 70.49 μm
# Epoch 130 | Total: 3120.6423 | Coord: 3119.9600 | Contrast: 6.8242 | MSE: 3094.69 | MeanDist: 70.49 μm
# Epoch 131 | Total: 3118.5508 | Coord: 3117.8687 | Contrast: 6.8223 | MSE: 3093.46 | MeanDist: 70.47 μm
# Epoch 131 | Total: 3118.5508 | Coord: 3117.8687 | Contrast: 6.8223 | MSE: 3093.46 | MeanDist: 70.47 μm
# Epoch 132 | Total: 3095.1016 | Coord: 3094.4199 | Contrast: 6.8159 | MSE: 3092.32 | MeanDist: 70.45 μm
# Epoch 132 | Total: 3095.1016 | Coord: 3094.4199 | Contrast: 6.8159 | MSE: 3092.32 | MeanDist: 70.45 μm
# Epoch 133 | Total: 3072.5369 | Coord: 3071.8547 | Contrast: 6.8210 | MSE: 3090.91 | MeanDist: 70.43 μm
# Epoch 133 | Total: 3072.5369 | Coord: 3071.8547 | Contrast: 6.8210 | MSE: 3090.91 | MeanDist: 70.43 μm
# Epoch 134 | Total: 3071.2341 | Coord: 3070.5522 | Contrast: 6.8195 | MSE: 3089.67 | MeanDist: 70.41 μm
# Epoch 134 | Total: 3071.2341 | Coord: 3070.5522 | Contrast: 6.8195 | MSE: 3089.67 | MeanDist: 70.41 μm
# Epoch 135 | Total: 3070.2144 | Coord: 3069.5322 | Contrast: 6.8212 | MSE: 3088.40 | MeanDist: 70.39 μm
# Epoch 135 | Total: 3070.2144 | Coord: 3069.5322 | Contrast: 6.8212 | MSE: 3088.40 | MeanDist: 70.39 μm
# Epoch 136 | Total: 3066.9695 | Coord: 3066.2891 | Contrast: 6.8037 | MSE: 3087.22 | MeanDist: 70.37 μm
# Epoch 136 | Total: 3066.9695 | Coord: 3066.2891 | Contrast: 6.8037 | MSE: 3087.22 | MeanDist: 70.37 μm
# Epoch 137 | Total: 3040.6587 | Coord: 3039.9766 | Contrast: 6.8214 | MSE: 3086.42 | MeanDist: 70.35 μm
# Epoch 137 | Total: 3040.6587 | Coord: 3039.9766 | Contrast: 6.8214 | MSE: 3086.42 | MeanDist: 70.35 μm
# Epoch 138 | Total: 3056.1155 | Coord: 3055.4341 | Contrast: 6.8151 | MSE: 3085.68 | MeanDist: 70.33 μm
# Epoch 138 | Total: 3056.1155 | Coord: 3055.4341 | Contrast: 6.8151 | MSE: 3085.68 | MeanDist: 70.33 μm
# Epoch 139 | Total: 3117.6758 | Coord: 3116.9949 | Contrast: 6.8103 | MSE: 3085.01 | MeanDist: 70.32 μm
# Epoch 139 | Total: 3117.6758 | Coord: 3116.9949 | Contrast: 6.8103 | MSE: 3085.01 | MeanDist: 70.32 μm
# Epoch 140 | Total: 3099.0884 | Coord: 3098.4067 | Contrast: 6.8163 | MSE: 3083.79 | MeanDist: 70.30 μm
# Epoch 140 | Total: 3099.0884 | Coord: 3098.4067 | Contrast: 6.8163 | MSE: 3083.79 | MeanDist: 70.30 μm
# Epoch 141 | Total: 3080.7510 | Coord: 3080.0696 | Contrast: 6.8145 | MSE: 3082.44 | MeanDist: 70.28 μm
# Epoch 141 | Total: 3080.7510 | Coord: 3080.0696 | Contrast: 6.8145 | MSE: 3082.44 | MeanDist: 70.28 μm
# Epoch 142 | Total: 3106.9668 | Coord: 3106.2849 | Contrast: 6.8178 | MSE: 3081.09 | MeanDist: 70.26 μm
# Epoch 142 | Total: 3106.9668 | Coord: 3106.2849 | Contrast: 6.8178 | MSE: 3081.09 | MeanDist: 70.26 μm
# Epoch 143 | Total: 3060.0752 | Coord: 3059.3936 | Contrast: 6.8158 | MSE: 3079.86 | MeanDist: 70.24 μm
# Epoch 143 | Total: 3060.0752 | Coord: 3059.3936 | Contrast: 6.8158 | MSE: 3079.86 | MeanDist: 70.24 μm
# Epoch 144 | Total: 3095.8389 | Coord: 3095.1577 | Contrast: 6.8117 | MSE: 3078.22 | MeanDist: 70.23 μm
# Epoch 144 | Total: 3095.8389 | Coord: 3095.1577 | Contrast: 6.8117 | MSE: 3078.22 | MeanDist: 70.23 μm
# Epoch 145 | Total: 3126.7117 | Coord: 3126.0305 | Contrast: 6.8126 | MSE: 3076.00 | MeanDist: 70.20 μm
# Epoch 145 | Total: 3126.7117 | Coord: 3126.0305 | Contrast: 6.8126 | MSE: 3076.00 | MeanDist: 70.20 μm
# Epoch 146 | Total: 3052.6760 | Coord: 3051.9954 | Contrast: 6.8055 | MSE: 3073.76 | MeanDist: 70.18 μm
# Epoch 146 | Total: 3052.6760 | Coord: 3051.9954 | Contrast: 6.8055 | MSE: 3073.76 | MeanDist: 70.18 μm
# Epoch 147 | Total: 3089.4377 | Coord: 3088.7578 | Contrast: 6.7983 | MSE: 3071.26 | MeanDist: 70.16 μm
# Epoch 147 | Total: 3089.4377 | Coord: 3088.7578 | Contrast: 6.7983 | MSE: 3071.26 | MeanDist: 70.16 μm
# Epoch 148 | Total: 3082.0825 | Coord: 3081.4021 | Contrast: 6.8038 | MSE: 3068.49 | MeanDist: 70.14 μm
# Epoch 148 | Total: 3082.0825 | Coord: 3081.4021 | Contrast: 6.8038 | MSE: 3068.49 | MeanDist: 70.14 μm
# Epoch 149 | Total: 3025.9937 | Coord: 3025.3132 | Contrast: 6.8036 | MSE: 3066.24 | MeanDist: 70.12 μm
# Epoch 149 | Total: 3025.9937 | Coord: 3025.3132 | Contrast: 6.8036 | MSE: 3066.24 | MeanDist: 70.12 μm
# Epoch 150 | Total: 3035.3967 | Coord: 3034.7175 | Contrast: 6.7926 | MSE: 3064.38 | MeanDist: 70.10 μm
# Epoch 150 | Total: 3035.3967 | Coord: 3034.7175 | Contrast: 6.7926 | MSE: 3064.38 | MeanDist: 70.10 μm
# Epoch 151 | Total: 3094.1980 | Coord: 3093.5193 | Contrast: 6.7872 | MSE: 3062.80 | MeanDist: 70.08 μm
# Epoch 151 | Total: 3094.1980 | Coord: 3093.5193 | Contrast: 6.7872 | MSE: 3062.80 | MeanDist: 70.08 μm
# Epoch 152 | Total: 3107.2234 | Coord: 3106.5449 | Contrast: 6.7851 | MSE: 3060.60 | MeanDist: 70.06 μm
# Epoch 152 | Total: 3107.2234 | Coord: 3106.5449 | Contrast: 6.7851 | MSE: 3060.60 | MeanDist: 70.06 μm
# Epoch 153 | Total: 3054.7568 | Coord: 3054.0779 | Contrast: 6.7885 | MSE: 3058.56 | MeanDist: 70.04 μm
# Epoch 153 | Total: 3054.7568 | Coord: 3054.0779 | Contrast: 6.7885 | MSE: 3058.56 | MeanDist: 70.04 μm
# Epoch 154 | Total: 3032.8540 | Coord: 3032.1741 | Contrast: 6.8003 | MSE: 3056.80 | MeanDist: 70.02 μm
# Epoch 154 | Total: 3032.8540 | Coord: 3032.1741 | Contrast: 6.8003 | MSE: 3056.80 | MeanDist: 70.02 μm
# Epoch 155 | Total: 3073.2063 | Coord: 3072.5259 | Contrast: 6.8038 | MSE: 3055.58 | MeanDist: 70.00 μm
# Epoch 155 | Total: 3073.2063 | Coord: 3072.5259 | Contrast: 6.8038 | MSE: 3055.58 | MeanDist: 70.00 μm
# Epoch 156 | Total: 3086.0728 | Coord: 3085.3940 | Contrast: 6.7863 | MSE: 3054.57 | MeanDist: 69.99 μm
# Epoch 156 | Total: 3086.0728 | Coord: 3085.3940 | Contrast: 6.7863 | MSE: 3054.57 | MeanDist: 69.99 μm
# Epoch 157 | Total: 3049.2168 | Coord: 3048.5383 | Contrast: 6.7843 | MSE: 3053.50 | MeanDist: 69.97 μm
# Epoch 157 | Total: 3049.2168 | Coord: 3048.5383 | Contrast: 6.7843 | MSE: 3053.50 | MeanDist: 69.97 μm
# Epoch 158 | Total: 3082.3145 | Coord: 3081.6355 | Contrast: 6.7889 | MSE: 3052.32 | MeanDist: 69.95 μm
# Epoch 158 | Total: 3082.3145 | Coord: 3081.6355 | Contrast: 6.7889 | MSE: 3052.32 | MeanDist: 69.95 μm
# Epoch 159 | Total: 3036.4241 | Coord: 3035.7454 | Contrast: 6.7871 | MSE: 3051.15 | MeanDist: 69.94 μm
# Epoch 159 | Total: 3036.4241 | Coord: 3035.7454 | Contrast: 6.7871 | MSE: 3051.15 | MeanDist: 69.94 μm
# Epoch 160 | Total: 3082.5591 | Coord: 3081.8799 | Contrast: 6.7911 | MSE: 3050.44 | MeanDist: 69.92 μm
# Epoch 160 | Total: 3082.5591 | Coord: 3081.8799 | Contrast: 6.7911 | MSE: 3050.44 | MeanDist: 69.92 μm
# Epoch 161 | Total: 3095.1130 | Coord: 3094.4348 | Contrast: 6.7823 | MSE: 3049.19 | MeanDist: 69.91 μm
# Epoch 161 | Total: 3095.1130 | Coord: 3094.4348 | Contrast: 6.7823 | MSE: 3049.19 | MeanDist: 69.91 μm
# Epoch 162 | Total: 3034.9587 | Coord: 3034.2798 | Contrast: 6.7883 | MSE: 3048.23 | MeanDist: 69.89 μm
# Epoch 162 | Total: 3034.9587 | Coord: 3034.2798 | Contrast: 6.7883 | MSE: 3048.23 | MeanDist: 69.89 μm
# Epoch 163 | Total: 3103.8225 | Coord: 3103.1436 | Contrast: 6.7894 | MSE: 3047.09 | MeanDist: 69.88 μm
# Epoch 163 | Total: 3103.8225 | Coord: 3103.1436 | Contrast: 6.7894 | MSE: 3047.09 | MeanDist: 69.88 μm
# Epoch 164 | Total: 3049.8721 | Coord: 3049.1929 | Contrast: 6.7914 | MSE: 3045.72 | MeanDist: 69.86 μm
# Epoch 164 | Total: 3049.8721 | Coord: 3049.1929 | Contrast: 6.7914 | MSE: 3045.72 | MeanDist: 69.86 μm
# Epoch 165 | Total: 2985.9663 | Coord: 2985.2866 | Contrast: 6.7968 | MSE: 3044.12 | MeanDist: 69.84 μm
# Epoch 165 | Total: 2985.9663 | Coord: 2985.2866 | Contrast: 6.7968 | MSE: 3044.12 | MeanDist: 69.84 μm
# Epoch 166 | Total: 3099.1555 | Coord: 3098.4771 | Contrast: 6.7853 | MSE: 3042.40 | MeanDist: 69.82 μm
# Epoch 166 | Total: 3099.1555 | Coord: 3098.4771 | Contrast: 6.7853 | MSE: 3042.40 | MeanDist: 69.82 μm
# Epoch 167 | Total: 3043.6604 | Coord: 3042.9827 | Contrast: 6.7771 | MSE: 3040.34 | MeanDist: 69.81 μm
# Epoch 167 | Total: 3043.6604 | Coord: 3042.9827 | Contrast: 6.7771 | MSE: 3040.34 | MeanDist: 69.81 μm
# Epoch 168 | Total: 3091.0688 | Coord: 3090.3892 | Contrast: 6.7969 | MSE: 3037.53 | MeanDist: 69.78 μm
# Epoch 168 | Total: 3091.0688 | Coord: 3090.3892 | Contrast: 6.7969 | MSE: 3037.53 | MeanDist: 69.78 μm
# Epoch 169 | Total: 3071.3274 | Coord: 3070.6499 | Contrast: 6.7759 | MSE: 3034.83 | MeanDist: 69.76 μm
# Epoch 169 | Total: 3071.3274 | Coord: 3070.6499 | Contrast: 6.7759 | MSE: 3034.83 | MeanDist: 69.76 μm
# Epoch 170 | Total: 3027.7517 | Coord: 3027.0737 | Contrast: 6.7788 | MSE: 3032.20 | MeanDist: 69.74 μm
# Epoch 170 | Total: 3027.7517 | Coord: 3027.0737 | Contrast: 6.7788 | MSE: 3032.20 | MeanDist: 69.74 μm
# Epoch 171 | Total: 3028.6609 | Coord: 3027.9822 | Contrast: 6.7879 | MSE: 3029.95 | MeanDist: 69.72 μm
# Epoch 171 | Total: 3028.6609 | Coord: 3027.9822 | Contrast: 6.7879 | MSE: 3029.95 | MeanDist: 69.72 μm
# Epoch 172 | Total: 3040.2126 | Coord: 3039.5359 | Contrast: 6.7687 | MSE: 3028.23 | MeanDist: 69.71 μm
# Epoch 172 | Total: 3040.2126 | Coord: 3039.5359 | Contrast: 6.7687 | MSE: 3028.23 | MeanDist: 69.71 μm
# Epoch 173 | Total: 3077.1641 | Coord: 3076.4858 | Contrast: 6.7827 | MSE: 3027.36 | MeanDist: 69.69 μm
# Epoch 173 | Total: 3077.1641 | Coord: 3076.4858 | Contrast: 6.7827 | MSE: 3027.36 | MeanDist: 69.69 μm
# Epoch 174 | Total: 3074.7107 | Coord: 3074.0330 | Contrast: 6.7783 | MSE: 3026.84 | MeanDist: 69.68 μm
# Epoch 174 | Total: 3074.7107 | Coord: 3074.0330 | Contrast: 6.7783 | MSE: 3026.84 | MeanDist: 69.68 μm
# Epoch 175 | Total: 3074.6353 | Coord: 3073.9568 | Contrast: 6.7857 | MSE: 3026.57 | MeanDist: 69.67 μm
# Epoch 175 | Total: 3074.6353 | Coord: 3073.9568 | Contrast: 6.7857 | MSE: 3026.57 | MeanDist: 69.67 μm
# Epoch 176 | Total: 3019.8452 | Coord: 3019.1672 | Contrast: 6.7802 | MSE: 3026.02 | MeanDist: 69.66 μm
# Epoch 176 | Total: 3019.8452 | Coord: 3019.1672 | Contrast: 6.7802 | MSE: 3026.02 | MeanDist: 69.66 μm
# Epoch 177 | Total: 3008.4297 | Coord: 3007.7512 | Contrast: 6.7847 | MSE: 3024.96 | MeanDist: 69.64 μm
# Epoch 177 | Total: 3008.4297 | Coord: 3007.7512 | Contrast: 6.7847 | MSE: 3024.96 | MeanDist: 69.64 μm
# Epoch 178 | Total: 3015.8167 | Coord: 3015.1387 | Contrast: 6.7804 | MSE: 3023.65 | MeanDist: 69.63 μm
# Epoch 178 | Total: 3015.8167 | Coord: 3015.1387 | Contrast: 6.7804 | MSE: 3023.65 | MeanDist: 69.63 μm
# Epoch 179 | Total: 3012.0959 | Coord: 3011.4185 | Contrast: 6.7755 | MSE: 3022.02 | MeanDist: 69.61 μm
# Epoch 179 | Total: 3012.0959 | Coord: 3011.4185 | Contrast: 6.7755 | MSE: 3022.02 | MeanDist: 69.61 μm
# Epoch 180 | Total: 3003.0745 | Coord: 3002.3967 | Contrast: 6.7783 | MSE: 3019.98 | MeanDist: 69.59 μm
# Epoch 180 | Total: 3003.0745 | Coord: 3002.3967 | Contrast: 6.7783 | MSE: 3019.98 | MeanDist: 69.59 μm
# Epoch 181 | Total: 3018.6189 | Coord: 3017.9412 | Contrast: 6.7770 | MSE: 3017.48 | MeanDist: 69.57 μm
# Epoch 181 | Total: 3018.6189 | Coord: 3017.9412 | Contrast: 6.7770 | MSE: 3017.48 | MeanDist: 69.57 μm
# Epoch 182 | Total: 3012.8186 | Coord: 3012.1406 | Contrast: 6.7791 | MSE: 3015.20 | MeanDist: 69.55 μm
# Epoch 182 | Total: 3012.8186 | Coord: 3012.1406 | Contrast: 6.7791 | MSE: 3015.20 | MeanDist: 69.55 μm
# Epoch 183 | Total: 3034.1101 | Coord: 3033.4331 | Contrast: 6.7696 | MSE: 3014.18 | MeanDist: 69.53 μm
# Epoch 183 | Total: 3034.1101 | Coord: 3033.4331 | Contrast: 6.7696 | MSE: 3014.18 | MeanDist: 69.53 μm
# Epoch 184 | Total: 3076.2710 | Coord: 3075.5928 | Contrast: 6.7823 | MSE: 3012.54 | MeanDist: 69.51 μm
# Epoch 184 | Total: 3076.2710 | Coord: 3075.5928 | Contrast: 6.7823 | MSE: 3012.54 | MeanDist: 69.51 μm
# Epoch 185 | Total: 2980.2817 | Coord: 2979.6057 | Contrast: 6.7602 | MSE: 3010.84 | MeanDist: 69.50 μm
# Epoch 185 | Total: 2980.2817 | Coord: 2979.6057 | Contrast: 6.7602 | MSE: 3010.84 | MeanDist: 69.50 μm
# Epoch 186 | Total: 3042.0657 | Coord: 3041.3901 | Contrast: 6.7561 | MSE: 3008.61 | MeanDist: 69.48 μm
# Epoch 186 | Total: 3042.0657 | Coord: 3041.3901 | Contrast: 6.7561 | MSE: 3008.61 | MeanDist: 69.48 μm
# Epoch 187 | Total: 3043.9263 | Coord: 3043.2495 | Contrast: 6.7684 | MSE: 3007.02 | MeanDist: 69.46 μm
# Epoch 187 | Total: 3043.9263 | Coord: 3043.2495 | Contrast: 6.7684 | MSE: 3007.02 | MeanDist: 69.46 μm
# Epoch 188 | Total: 3002.0410 | Coord: 3001.3645 | Contrast: 6.7640 | MSE: 3005.57 | MeanDist: 69.44 μm
# Epoch 188 | Total: 3002.0410 | Coord: 3001.3645 | Contrast: 6.7640 | MSE: 3005.57 | MeanDist: 69.44 μm
# Epoch 189 | Total: 2968.2019 | Coord: 2967.5244 | Contrast: 6.7740 | MSE: 3004.33 | MeanDist: 69.42 μm
# Epoch 189 | Total: 2968.2019 | Coord: 2967.5244 | Contrast: 6.7740 | MSE: 3004.33 | MeanDist: 69.42 μm
# Epoch 190 | Total: 3031.6033 | Coord: 3030.9260 | Contrast: 6.7721 | MSE: 3003.46 | MeanDist: 69.41 μm
# Epoch 190 | Total: 3031.6033 | Coord: 3030.9260 | Contrast: 6.7721 | MSE: 3003.46 | MeanDist: 69.41 μm
# Epoch 191 | Total: 2994.9526 | Coord: 2994.2759 | Contrast: 6.7678 | MSE: 3002.77 | MeanDist: 69.39 μm
# Epoch 191 | Total: 2994.9526 | Coord: 2994.2759 | Contrast: 6.7678 | MSE: 3002.77 | MeanDist: 69.39 μm
# Epoch 192 | Total: 3008.1853 | Coord: 3007.5095 | Contrast: 6.7567 | MSE: 3002.00 | MeanDist: 69.38 μm
# Epoch 192 | Total: 3008.1853 | Coord: 3007.5095 | Contrast: 6.7567 | MSE: 3002.00 | MeanDist: 69.38 μm
# Epoch 193 | Total: 2974.2937 | Coord: 2973.6160 | Contrast: 6.7780 | MSE: 3001.27 | MeanDist: 69.36 μm
# Epoch 193 | Total: 2974.2937 | Coord: 2973.6160 | Contrast: 6.7780 | MSE: 3001.27 | MeanDist: 69.36 μm
# Epoch 194 | Total: 3013.4011 | Coord: 3012.7253 | Contrast: 6.7586 | MSE: 3000.65 | MeanDist: 69.35 μm
# Epoch 194 | Total: 3013.4011 | Coord: 3012.7253 | Contrast: 6.7586 | MSE: 3000.65 | MeanDist: 69.35 μm
# Epoch 195 | Total: 3017.7349 | Coord: 3017.0591 | Contrast: 6.7577 | MSE: 2999.89 | MeanDist: 69.34 μm
# Epoch 195 | Total: 3017.7349 | Coord: 3017.0591 | Contrast: 6.7577 | MSE: 2999.89 | MeanDist: 69.34 μm
# Epoch 196 | Total: 2924.4031 | Coord: 2923.7261 | Contrast: 6.7692 | MSE: 2999.16 | MeanDist: 69.32 μm
# Epoch 196 | Total: 2924.4031 | Coord: 2923.7261 | Contrast: 6.7692 | MSE: 2999.16 | MeanDist: 69.32 μm
# Epoch 197 | Total: 3006.8694 | Coord: 3006.1929 | Contrast: 6.7654 | MSE: 2998.80 | MeanDist: 69.31 μm
# Epoch 197 | Total: 3006.8694 | Coord: 3006.1929 | Contrast: 6.7654 | MSE: 2998.80 | MeanDist: 69.31 μm
# Epoch 198 | Total: 3031.2388 | Coord: 3030.5632 | Contrast: 6.7545 | MSE: 2997.83 | MeanDist: 69.30 μm
# Epoch 198 | Total: 3031.2388 | Coord: 3030.5632 | Contrast: 6.7545 | MSE: 2997.83 | MeanDist: 69.30 μm
# Epoch 199 | Total: 3033.4485 | Coord: 3032.7720 | Contrast: 6.7639 | MSE: 2995.59 | MeanDist: 69.28 μm
# Training finished in 196.0s
# Epoch 199 | Total: 3033.4485 | Coord: 3032.7720 | Contrast: 6.7639 | MSE: 2995.59 | MeanDist: 69.28 μm
# Training finished in 196.0s

# %% [markdown]
# ## 6. Evaluate Contrastive Learning Results
#
# Let's evaluate our model's performance on the coordinate prediction task.

# %%
# Evaluate the contrastive model
results = evaluate_contrastive_model(contrastive_model, data)

# Print results
print("COORDINATE PREDICTION RESULTS:")
print(f"Mean Squared Error: {results['mse']:.4f}")
print(f"Mean Absolute Error: {results['mae']:.4f}")
print(f"Mean Distance Error: {results['mean_distance_error']:.2f} μm")
print(f"Median Distance Error: {results['median_distance_error']:.2f} μm")
print(f"X-coordinate correlation: {results['correlation_x']:.4f}")
print(f"Y-coordinate correlation: {results['correlation_y']:.4f}")

# Visualize predictions
def visualize_predictions(data, model):
    model.eval()
    with torch.no_grad():
        pred_coords = model(data)
    
    # Get coordinates and predictions
    true_coords = data.target_coords.numpy()
    pred_coords_np = pred_coords.numpy()
    
    visible_mask = data.visible_mask.numpy()
    hidden_mask = data.hidden_mask.numpy()
    
    plt.figure(figsize=(10, 8))
    
    # Plot visible nodes
    plt.scatter(true_coords[visible_mask, 0], true_coords[visible_mask, 1], 
               c='blue', alpha=0.6, s=20, label='Visible nodes')
    
    # Plot true hidden nodes
    plt.scatter(true_coords[hidden_mask, 0], true_coords[hidden_mask, 1], 
               c='red', alpha=0.8, s=20, label='True hidden')
    
    # Plot predicted hidden nodes
    plt.scatter(pred_coords_np[hidden_mask, 0], pred_coords_np[hidden_mask, 1], 
               c='orange', alpha=0.8, s=20, label='Predicted hidden')
    
    # Draw error lines
    for i in np.where(hidden_mask)[0]:
        plt.plot([true_coords[i, 0], pred_coords_np[i, 0]], 
                [true_coords[i, 1], pred_coords_np[i, 1]], 
                'r-', alpha=0.3, linewidth=0.5)
    
    plt.title('Contrastive GCN Predictions')
    plt.legend()
    plt.axis('equal')
    plt.show()

# Visualize predictions
visualize_predictions(data, contrastive_model)
# Out:
# COORDINATE PREDICTION RESULTS:
# Mean Squared Error: 2995.5891
# Mean Absolute Error: 43.5282
# Mean Distance Error: 69.28 μm
# Median Distance Error: 76.76 μm
# X-coordinate correlation: 0.2336
# Y-coordinate correlation: 0.0348

# %% [markdown]
# ## 7. Next Steps and Further Exploration
#
# With this notebook, you've seen how contrastive learning can be applied to your nuclei coordinate prediction task. For a full training run and comparison with the standard GCN approach, run the `main_contrastive.py` script.
#
# Some directions for further exploration:
#
# 1. **Augmentation strategies**: Experiment with different graph augmentations like subgraph sampling, edge perturbation, and feature normalization.
#
# 2. **Projection head design**: Try different architectures for the projection head used in contrastive learning.
#
# 3. **Contrastive loss variants**: Implement other contrastive objectives like BYOL, MoCo, or SimCLR.
#
# 4. **Nuclei clustering**: Use the learned embeddings to cluster nuclei and identify regions with similar topological properties.
#
# 5. **Transfer learning**: Apply the pre-trained model to other related tasks or datasets.

# %%
# Example of analyzing learned embeddings
def analyze_embeddings(model, data):
    model.eval()
    with torch.no_grad():
        _, embeddings = model(data, return_embeddings=True)
    
    # Convert to numpy for analysis
    embeddings_np = embeddings.numpy()
    
    # Perform dimensionality reduction for visualization
    from sklearn.decomposition import PCA
    from sklearn.manifold import TSNE
    
    # PCA
    pca = PCA(n_components=2)
    embeddings_pca = pca.fit_transform(embeddings_np)
    
    # t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    embeddings_tsne = tsne.fit_transform(embeddings_np)
    
    # Visualize embeddings colored by spatial position
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # For color, use original spatial positions
    coords = data.target_coords.numpy()
    
    # PCA plot
    scatter1 = ax1.scatter(embeddings_pca[:, 0], embeddings_pca[:, 1], 
                          c=coords[:, 0], cmap='viridis', alpha=0.7, s=5)
    ax1.set_title('PCA of Node Embeddings\nColored by X-coordinate')
    ax1.set_xlabel('PC1')
    ax1.set_ylabel('PC2')
    plt.colorbar(scatter1, ax=ax1, label='X-coordinate')
    
    # t-SNE plot
    scatter2 = ax2.scatter(embeddings_tsne[:, 0], embeddings_tsne[:, 1], 
                          c=coords[:, 1], cmap='plasma', alpha=0.7, s=5)
    ax2.set_title('t-SNE of Node Embeddings\nColored by Y-coordinate')
    ax2.set_xlabel('t-SNE 1')
    ax2.set_ylabel('t-SNE 2')
    plt.colorbar(scatter2, ax=ax2, label='Y-coordinate')
    
    plt.tight_layout()
    plt.show()

# Analyze embeddings (note: with only 10 epochs of training, these won't be very informative yet)
print("Analyzing learned embeddings...")
analyze_embeddings(contrastive_model, data)

print("\nTo get better results, run the full training in main_contrastive.py")
print("python main_contrastive.py")
# Out:
# Analyzing learned embeddings...
# To get better results, run the full training in main_contrastive.py
# python main_contrastive.py
